# %% [markdown]
# # **DataCon 2024: Data Quality Checks**
# #### Learn how to run simple Completeness, Consistency and Accuracy Checks based on pre-defined validation rules on a sample Sales Dataset

# %% [markdown]
# ## Import Pandas Library and Load Data from File

# %%
#Import external libraries
# %pip install pandas

# imports the 'pandas' library for use in this script and assigns it the nickname 'pd'
import pandas as pd

# %%
import pandas as pd

# %%
# loading the data from sales.csv into the DataFrame object
df = pd.read_csv('sales.csv')
df.index = df.index + 1

# %% [markdown]
# #### Some DataFrame functions built into `pandas`:

# %%
df.head() # returns first 5 rows of table
# Out:
#     SalesDate SalesID CustomerID SalesPersonID ProductID Quantity   Sales  \
# 1  2020-01-01     112         37             9        70        7   226.0
# 2  2020-01-01     113         59             4        36       37   326.1
# 3  2020-01-01     114         59             4        40       19   422.9
# 4  2020-01-01     115          3             9        11       60  1683.8
# 5  2020-01-01     116          3             9        40       12   230.9
#
#         StoreID OrderStatus
# 1             9  Incomplete
# 2             7     Pending
# 3             7  Incomplete
# 4  nd68G6h0PZbk     Pending
# 5             7  Incomplete

# %%
l = len(df) # returns number of rows in table
print(l)
# Out:
# 8498

# %%
df['SalesID'] # get SalesID column
# Out:
# 1        112
# 2        113
# 3        114
# 4        115
# 5        116
#         ...
# 8494    2843
# 8495    2677
# 8496    2844
# 8497    2678
# 8498    2845
# Name: SalesID, Length: 8498, dtype: object

# %%
df.loc[1] # get 1st row
# Out:
# SalesDate        2020-01-01
# SalesID                 112
# CustomerID               37
# SalesPersonID             9
# ProductID                70
# Quantity                  7
# Sales                 226.0
# StoreID                   9
# OrderStatus      Incomplete
# Name: 1, dtype: object

# %%
df.loc[1]['SalesID'] # get 1st row of SalesID column
# Out:
# '112'

# %%
column_names = list(df) # returns list of column names in table
print(column_names)
# Out:
# ['SalesDate', 'SalesID', 'CustomerID', 'SalesPersonID', 'ProductID', 'Quantity', 'Sales', 'StoreID', 'OrderStatus']

# %% [markdown]
# ## Define and Run Data Quality Check Functions
# Each function checks the values in 1 row against 1 validation rule.<br>
# ## Check for **Completeness** of dataset

# %%
#Defining the Completeness check function
def check_cannot_be_blank (df, column_name): # returns true if column_name contains no blanks
  column_values = df[column_name]
  for column_value in column_values:
    if pd.isna(column_value): # pd.isna(column_value) returns False if column_value is blank
      return False
  return True

# %%
#Run the cannot be blank (i.e. completeness) check on a specific column (i.e. SalesID)
print(check_cannot_be_blank(df, 'SalesID'))
# Out:
# True

# %%
#Use a `for` loop to run the **Completeness** check on all columns in the table
for column_name in column_names:
  print(column_name + ': ' + str(check_cannot_be_blank(df, column_name)))
# Out:
# SalesDate: True
# SalesID: True
# CustomerID: True
# SalesPersonID: True
# ProductID: True
# Quantity: True
# Sales: True
# StoreID: True
# OrderStatus: True

# %% [markdown]
# ## Check for **Consistency** of dataset
# ### Start with SalesDate Column in dataset

# %%
#Define the Consistency check function

from collections import defaultdict
import math

def is_intable (s): # returns true if the input value is an integer
  try:
    int(s)
  except:
    return False
  return True

def is_floatable (s): # returns true if the input value is a float
  try:
    float(s)
  except:
    return False
  return True

def is_alphabetical (s): # returns true if the input value is alphabetical (consists only of alphabets)
  if not isinstance(s, str):
    return False
  for char in s: # for each character in the input string
    if ord(char) not in range(97,123) and ord(char) not in range(65,91): # if the character is not in a-z or A-Z
      return False # the value is not alphabetical
  return True

def check_data_format (df, column_name, character_type, pieces_max_lengths): # returns true if all values in column_name comply with data format specified
  match character_type:
    case 'N': # if character type is 'N'
      if len(pieces_max_lengths) == 2: # data format is N(p,q)
        for value in df[column_name]: # for each value in the column
          val_str = str(value) # convert the value into a string
          val_str_pieces = val_str.split('.') # split the string into before and after the decimal point
          if len(val_str_pieces) != 2:
            return False # the column fails the check if number of '.' is not exactly 1
          # the value passes the check if both pieces are integers, and each piece is of length less than or equal to the maximum length specified
          complies = is_intable(val_str_pieces[0]) and is_intable(val_str_pieces[1]) and len(val_str_pieces[0]) <= pieces_max_lengths[0] and len(val_str_pieces[1]) <= pieces_max_lengths[1]
          if not complies:
            return False
        return True
      elif len(pieces_max_lengths) == 1: # data format is N(p)
        for value in df[column_name]:
          complies = is_intable(value) and len(str(value)) <= pieces_max_lengths[0] # the value passes the check if it is an integer and is of length less than or equal to the maximum length specified
          if not complies:
            return False
        return True
    case 'A': # data format is A(p)
      for value in df[column_name]:
        complies = is_alphabetical(value) and len(value) <= pieces_max_lengths[0] # the value passes the check if it is alphabetical and is of length less than or equal to the maximum length specified
        if not complies:
          return False
      return True
    case 'X': # data format is X(p)
      for value in df[column_name]:
        val_str = str(value) # convert the value into a string
        complies = len(val_str) <= pieces_max_lengths[0] # the value passes the check if it is of length less than or equal to the maximum length specified
        if not complies:
          return False
      return True

def check_date_format_yyyymmdd (df, column_name): # returns true if all values in column_name follow the date format yyyy-mm-dd
  for value in df[column_name]:
    value_split = value.split('-') # split each value into 3 parts to assess individually
    if len(value_split) != 3:
      return False # column fails the check if the number of parts is not exactly 3
    try:
      if len(value_split[2]) != 2 or int(value_split[2]) < 0 or int(value_split[2]) > 31: # reject if date is not 2 digits, or date < 0 or date > 31
        return False
      if len(value_split[2]) != 2 or int(value_split[1]) < 0 or int(value_split[1]) > 12: # reject if month is not 2 digits, or month < 0 or month > 12
        return False
      if len(value_split[0]) != 4 or not is_intable(value_split[0]): # reject if year is not int or year is not 4 digits
        return False
    except:
      return False # reject if date, month or year is not an integer
  return True

# %%
#Run the Consistency check on SalesDate column
print('Check SalesDate column')
print('====')
print('Data format: ' + str(check_data_format(df, 'SalesDate', 'X', [10])))
print('Date format: ' + str(check_date_format_yyyymmdd(df, 'SalesDate')))
# Out:
# Check SalesDate column
# ====
# Data format: False
# Date format: False

# %% [markdown]
# #### Modify the functions to investigate the rows that fail to comply with the **Consistency** rules:

# %%
def data_format_identify_non_complying_rows (df, column_name, character_type, pieces_max_lengths): # returns a list of row(s) that do not comply to data format rule
  non_compliers = [] # keep a list of rows that do not comply to this rule
  match character_type:
    case 'N':
      if len(pieces_max_lengths) == 2: # data format is N(p,q)
        for index in range(1, l + 1):
          val_str = str(df.loc[index][column_name]) # locate the row in  the specified column that does not comply with this rule
          val_str_pieces = val_str.split('.')
          complies = len(val_str_pieces) == 2 and is_intable(val_str_pieces[0]) and is_intable(val_str_pieces[1]) and len(val_str_pieces[0]) <= pieces_max_lengths[0] and len(val_str_pieces[1]) <= pieces_max_lengths[1]
          if not complies:
            non_compliers.append(df.loc[index]) # if the value does not comply then add the row to the list of non-compliers
        return non_compliers
      elif len(pieces_max_lengths) == 1: # data format is N(p)
        for index in range(1, l + 1):
          value = df.loc[index][column_name]
          complies = is_intable(value) and len(str(value)) <= pieces_max_lengths[0]
          if not complies:
            non_compliers.append(df.loc[index]) # if the value does not comply then add the row to the list of non-compliers
        return non_compliers
    case 'A': # data format is A(p)
      for index in range(1, l + 1):
          value = df.loc[index][column_name]
          complies = is_alphabetical(value) and len(value) <= pieces_max_lengths[0]
          if not complies:
            non_compliers.append(df.loc[index]) # if the value does not comply then add the row to the list of non-compliers
      return non_compliers
    case 'X': # data format is X(p)
      for index in range(1, l + 1):
          value = df.loc[index][column_name]
          complies = len(value) <= pieces_max_lengths[0]
          if not complies:
            non_compliers.append(df.loc[index]) # if the value does not comply then add the row to the list of non-compliers
      return non_compliers

def date_format_identify_non_complying_rows (df, column_name): # returns a list of row(s) that do not comply to date format rule
  non_compliers = [] # keep a list of rows that do not comply to this rule
  for row_index in range(1, l + 1): # going through the df row by row this time
    value_complies = True
    value = df.loc[row_index][column_name] # locate the row in  the specified column that does not comply with this rule
    value_split = value.split('-') # split each value into 3 parts to assess individually
    if len(value_split) != 3:
      value_complies = False # column fails the check if the number of parts is not exactly 3
    try:
      if int(value_split[2]) < 0 or int(value_split[2]) > 31: # reject if date is not int or date < 0 or date > 31
        value_complies = False
      if int(value_split[1]) < 0 or int(value_split[1]) > 12: # reject if month is not int or month < 0 or month > 12
        value_complies = False
      if len(value_split[0]) != 4 or not is_intable(value_split[0]): # reject if year is not int or year is not 4 digits
        value_complies = False
    except:
      value_complies = False # also reject row if date, month or year is not an integer
    if value_complies == False:
        non_compliers.append(df.loc[row_index]) # add the row to the list of non-compliers
  return non_compliers

# %% [markdown]
# #### Define a helper function to print relevant rows neatly

# %%
def pprint_row_list (lis): # prints a list of rows in a nice format
  for i in range(len(lis)): # for each item in the list
    print('Item number ' + str(i + 1)) # print the item number (position in list)
    print(lis[i]) # print the item
    print('\n') # print a line break

# %% [markdown]
# #### Run the modified **Consistency** check function to display all rows with errors

# %%
print('SalesDate non-complying rows for data format :')
pprint_row_list(data_format_identify_non_complying_rows(df, 'SalesDate', 'X', [10]))
print('\n')

print('SalesDate non-complying rows for date format :')
pprint_row_list(date_format_identify_non_complying_rows(df, 'SalesDate'))
# Out:
# SalesDate non-complying rows for data format :
# Item number 1
# SalesDate        4KJlZDR2y8ary
# SalesID                   1810
# CustomerID                  37
# SalesPersonID                3
# ProductID                   64
# Quantity                     7
# Sales                    311.4
# StoreID                      2
# OrderStatus           Complete
# Name: 1775, dtype: object
#
#
# Item number 2
# SalesDate        g9q7jkijclM4tCu
# SalesID                     2227
# CustomerID                    19
# SalesPersonID                  3
# ProductID                      2
# Quantity                      26
# Sales                      461.0
# StoreID                        3
# OrderStatus             Complete
# Name: 2230, dtype: object
#
#
# Item number 3
# SalesDate        2xN93XPWEgreAXJCkfM
# SalesID                         3685
# CustomerID                        63
# SalesPersonID                      7
# ProductID                         44
# Quantity                          21
# Sales                         1805.1
# StoreID                            7
# OrderStatus                 Complete
# Name: 3059, dtype: object
#
#
#
#
# SalesDate non-complying rows for date format :
# Item number 1
# SalesDate          mGetkX
# SalesID               164
# CustomerID              5
# SalesPersonID           2
# ProductID              44
# Quantity               18
# Sales              1339.8
# StoreID                 8
# OrderStatus      Complete
# Name: 741, dtype: object
#
#
# Item number 2
# SalesDate               U
# SalesID              1125
# CustomerID              5
# SalesPersonID           3
# ProductID              54
# Quantity               18
# Sales               690.5
# StoreID                 6
# OrderStatus      Complete
# Name: 1243, dtype: object
#
#
# Item number 3
# SalesDate        4KJlZDR2y8ary
# SalesID                   1810
# CustomerID                  37
# SalesPersonID                3
# ProductID                   64
# Quantity                     7
# Sales                    311.4
# StoreID                      2
# OrderStatus           Complete
# Name: 1775, dtype: object
#
#
# Item number 4
# SalesDate               e
# SalesID              2029
# CustomerID             37
# SalesPersonID           2
# ProductID              36
# Quantity               39
# Sales               268.1
# StoreID                 4
# OrderStatus      Complete
# Name: 1994, dtype: object
#
#
# Item number 5
# SalesDate        g9q7jkijclM4tCu
# SalesID                     2227
# CustomerID                    19
# SalesPersonID                  3
# ProductID                      2
# Quantity                      26
# Sales                      461.0
# StoreID                        3
# OrderStatus             Complete
# Name: 2230, dtype: object
#
#
# Item number 6
# SalesDate             wiw
# SalesID              2381
# CustomerID             80
# SalesPersonID           1
# ProductID              61
# Quantity               29
# Sales               927.8
# StoreID                 5
# OrderStatus      Complete
# Name: 2384, dtype: object
#
#
# Item number 7
# SalesDate              V5
# SalesID              3459
# CustomerID             59
# SalesPersonID           5
# ProductID              31
# Quantity                9
# Sales                69.1
# StoreID                 9
# OrderStatus      Complete
# Name: 2805, dtype: object
#
#
# Item number 8
# SalesDate               Q
# SalesID              3544
# CustomerID             32
# SalesPersonID           1
# ProductID              46
# Quantity               43
# Sales               672.7
# StoreID                 5
# OrderStatus      Complete
# Name: 2894, dtype: object
#
#
# Item number 9
# SalesDate           UFa3b
# SalesID              3658
# CustomerID             85
# SalesPersonID           5
# ProductID              71
# Quantity               20
# Sales               623.4
# StoreID                 4
# OrderStatus      Complete
# Name: 3028, dtype: object
#
#
# Item number 10
# SalesDate        2xN93XPWEgreAXJCkfM
# SalesID                         3685
# CustomerID                        63
# SalesPersonID                      7
# ProductID                         44
# Quantity                          21
# Sales                         1805.1
# StoreID                            7
# OrderStatus                 Complete
# Name: 3059, dtype: object
#
#
# Item number 11
# SalesDate              Lg
# SalesID              3777
# CustomerID             84
# SalesPersonID           4
# ProductID              70
# Quantity               36
# Sales               842.7
# StoreID                 2
# OrderStatus      Complete
# Name: 3296, dtype: object
#
#
# Item number 12
# SalesDate               9
# SalesID              3917
# CustomerID             14
# SalesPersonID           6
# ProductID              51
# Quantity                3
# Sales               316.6
# StoreID                 5
# OrderStatus      Complete
# Name: 3436, dtype: object
#
#
# Item number 13
# SalesDate              Uj
# SalesID              4021
# CustomerID              1
# SalesPersonID           7
# ProductID              59
# Quantity               17
# Sales               123.2
# StoreID                 7
# OrderStatus      Complete
# Name: 3540, dtype: object
#
#
# Item number 14
# SalesDate        y5McwSjhR
# SalesID               4114
# CustomerID              32
# SalesPersonID            4
# ProductID               43
# Quantity                44
# Sales                510.5
# StoreID                  4
# OrderStatus       Complete
# Name: 3633, dtype: object
#
#
# Item number 15
# SalesDate        2021-14-04
# SalesID                3160
# CustomerID               64
# SalesPersonID             2
# ProductID                51
# Quantity                  7
# Sales                 797.3
# StoreID                   4
# OrderStatus        Complete
# Name: 4809, dtype: object
#
#
# Item number 16
# SalesDate            4ga3
# SalesID              5584
# CustomerID              5
# SalesPersonID           3
# ProductID              30
# Quantity               35
# Sales               859.0
# StoreID                 2
# OrderStatus      Complete
# Name: 5289, dtype: object
#
#
# Item number 17
# SalesDate               8
# SalesID              6158
# CustomerID             91
# SalesPersonID           8
# ProductID              75
# Quantity               32
# Sales               284.5
# StoreID                 1
# OrderStatus      Complete
# Name: 5937, dtype: object
#
#
# Item number 18
# SalesDate            IR7s
# SalesID              7633
# CustomerID             80
# SalesPersonID           1
# ProductID              71
# Quantity                2
# Sales                55.4
# StoreID                 1
# OrderStatus      Complete
# Name: 7489, dtype: object
#
#
# Item number 19
# SalesDate        2021-30-09
# SalesID                2622
# CustomerID               42
# SalesPersonID             1
# ProductID                16
# Quantity                 48
# Sales                 379.2
# StoreID                   8
# OrderStatus        Complete
# Name: 7718, dtype: object
#
#
# Item number 20
# SalesDate         zB7GRDx
# SalesID              2629
# CustomerID             37
# SalesPersonID           9
# ProductID              68
# Quantity               49
# Sales               685.3
# StoreID                 1
# OrderStatus      Complete
# Name: 7947, dtype: object

# %% [markdown]
# #### Modify the functions again to provide a percentage of all rows that do not comply with the specified **Consistency** rules:

# %%
# returns the percentage of row(s) that do not comply to data format rule
def data_format_percentage_non_compliance (df, column_name, character_type, pieces_max_lengths):
  return len(data_format_identify_non_complying_rows(df, column_name, character_type, pieces_max_lengths)) / l * 100

# returns the percentage of row(s) that do not comply to date format rule
def date_format_percentage_non_compliance (df, column_name):
  return len(date_format_identify_non_complying_rows(df, column_name)) / l * 100

# %% [markdown]
# #### Run the modified checks to find the percentage non-compliance of the SalesDate column for each of the **Consistency** checks:

# %%
print('Consistency checks:')
print('======')
print('SalesDate percentage non-compliance for data format rule: ' + str(data_format_percentage_non_compliance(df, 'SalesDate', 'X', [10])))
print('SalesDate percentage non-compliance for date format rule: ' + str(date_format_percentage_non_compliance(df, 'SalesDate')))
# Out:
# Consistency checks:
# ======
# SalesDate percentage non-compliance for data format rule: 0.03530242409978819
# SalesDate percentage non-compliance for date format rule: 0.2353494939985879

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** score:

# %%
sales_date_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'SalesDate', 'X', [10]) + date_format_percentage_non_compliance(df, 'SalesDate')) / 2
print('Consistency score: ' + str(sales_date_consistency_score))

sales_date_accuracy_score = 100 # SalesDate column has no accuracy rules / checks
print('Accuracy score: ' + str(sales_date_accuracy_score))
# Out:
# Consistency score: 99.86467404095082
# Accuracy score: 100

# %% [markdown]
# ### Find non-complying rows
# #### Define the rest of the **Consistency** validation check functions to also return a list of non-complying rows:

# %%
def unique_values_identify_non_complying_rows (df, column_name): # returns a list of row(s) that do not comply to unique values rule
  non_compliers = [] # keep a list of rows that do not comply to this rule
  value_occurence_list = defaultdict(list) # for each value that occurs in the column, keep a list of rows that have this value
  for index in range(1,l + 1): # remember l is len(df)
    value = df.loc[index][column_name] # locate the row in  the specified column that does not comply with this rule
    value_occurence_list[value].append(index) # add the row to the list of rows with the same value in that column
  for value in value_occurence_list.keys(): # for each value in the column,
    if len(value_occurence_list[value]) > 1: # if there is more than 1 row in the list of rows with that value
      non_compliers = non_compliers + [df.loc[index] for index in value_occurence_list[value]] # add all the rows in the list to the list of non-compliers
  return non_compliers

def data_type_identify_non_complying_rows (df, column_name, type_specified): # returns a list of rows that do not comply with data type rule (Integer, Float etc.)
  non_compliers = [] # keep a list of rows that do not comply to this rule
  for index in range(1, l + 1):
    value = df.loc[index][column_name] # locate the row in  the specified column that does not comply with this rule
    if type_specified == int:
      if not is_intable(value):
        non_compliers.append(df.loc[index])
    elif type_specified == float:
      if not is_floatable(value):
        non_compliers.append(df.loc[index])
  return non_compliers

# %% [markdown]
# #### Define the rest of the **Accuracy** validation check functions to also return a list of non-complying rows:

# %%
def numerical_range_identify_non_complying_rows (df, column_name, lower_bound = - math.inf, upper_bound = math.inf): # returns a list of row(s) that do not comply to numerical range rule
  non_compliers = [] # keep a list of rows that do not comply to this rule
  for index in range(1, l + 1):
    value = df.loc[index][column_name] # locate the row in  the specified column that does not comply with this rule
    try:
      if float(value) >= upper_bound or float(value) <= lower_bound: # if value in row is not within specified range
        non_compliers.append(df.loc[index]) # add the row to the list of non-compliers
    except:
      non_compliers.append(df.loc[index]) # also add the row to the list of non-compliers if value is not numerical
  return non_compliers

# %% [markdown]
# #### Calculate percentage non-compliance per-column for the **Consistency** checks

# %%
# returns the percentage of row(s) that do not comply to unique values rule
def unique_values_percentage_non_compliance (df, column_name):
  return len(unique_values_identify_non_complying_rows(df, column_name)) / l * 100

# returns the percentage of row(s) that do not comply to data type rule
def data_type_percentage_non_compliance (df, column_name, type_specified):
  return len(data_type_identify_non_complying_rows(df, column_name, type_specified)) / l * 100

# %% [markdown]
# #### Calculate  percentage non-compliance per-column for the **Accuracy** checks

# %%
# returns the percentage of row(s) that do not comply to numerical range rule
def numerical_range_percentage_non_compliance (df, column_name, lower_bound = - math.inf, upper_bound = math.inf):
  return len(numerical_range_identify_non_complying_rows(df, column_name, lower_bound, upper_bound)) / l * 100

# %% [markdown]
# ### Move on to validation checks for SalesID column
# #### Identify rows in SalesID column that do not comply with **Consistency** and **Accuracy** rules

# %%
print('Consistency checks:')
print('======')
print('SalesID non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'SalesID', 'N', [4]))
print('\n')

print('SalesID non-complying rows for unique values rule:')
pprint_row_list(unique_values_identify_non_complying_rows(df, 'SalesID'))
print('\n')

print('SalesID non-complying rows for Integer type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'SalesID', int))
print('\n')

print('Accuracy checks:')
print('======')
print('SalesID non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'SalesID', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# SalesID non-complying rows for data format:
# Item number 1
# SalesDate        2020-02-02
# SalesID                   y
# CustomerID               79
# SalesPersonID             7
# ProductID                52
# Quantity                 23
# Sales                1702.3
# StoreID                   9
# OrderStatus        Complete
# Name: 597, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-10
# SalesID                  FH
# CustomerID                5
# SalesPersonID             2
# ProductID                73
# Quantity                 27
# Sales                  29.1
# StoreID                   4
# OrderStatus        Complete
# Name: 676, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-03
# SalesID                   Q
# CustomerID               44
# SalesPersonID             8
# ProductID                30
# Quantity                 15
# Sales                 488.3
# StoreID                   3
# OrderStatus        Complete
# Name: 970, dtype: object
#
#
# Item number 4
# SalesDate        2020-08-28
# SalesID               4Uipa
# CustomerID               37
# SalesPersonID             9
# ProductID                30
# Quantity                 44
# Sales                1130.4
# StoreID                   5
# OrderStatus        Complete
# Name: 2030, dtype: object
#
#
# Item number 5
# SalesDate        2020-09-09
# SalesID            7Uk9tk44
# CustomerID               19
# SalesPersonID             9
# ProductID                35
# Quantity                 33
# Sales                 230.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2128, dtype: object
#
#
# Item number 6
# SalesDate        2021-01-02
# SalesID                   v
# CustomerID               32
# SalesPersonID             1
# ProductID                 1
# Quantity                 36
# Sales                 665.6
# StoreID                   5
# OrderStatus        Complete
# Name: 2719, dtype: object
#
#
# Item number 7
# SalesDate             2021-02-01
# SalesID          yFq2zNd0oKIwNKx
# CustomerID                    48
# SalesPersonID                  1
# ProductID                     76
# Quantity                      10
# Sales                     4000.6
# StoreID                        1
# OrderStatus             Complete
# Name: 3351, dtype: object
#
#
# Item number 8
# SalesDate        2021-02-09
# SalesID                  qD
# CustomerID               63
# SalesPersonID             7
# ProductID                74
# Quantity                 17
# Sales                 634.9
# StoreID                   8
# OrderStatus        Complete
# Name: 3637, dtype: object
#
#
# Item number 9
# SalesDate        2021-03-02
# SalesID            D6LEy6eD
# CustomerID               73
# SalesPersonID             9
# ProductID                56
# Quantity                 29
# Sales                1127.5
# StoreID                   3
# OrderStatus        Complete
# Name: 3873, dtype: object
#
#
# Item number 10
# SalesDate        2021-04-07
# SalesID               BO5wH
# CustomerID               17
# SalesPersonID             8
# ProductID                26
# Quantity                 12
# Sales                 342.6
# StoreID                   5
# OrderStatus        Complete
# Name: 4689, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-19
# SalesID          g1UQTsSvUk
# CustomerID               41
# SalesPersonID             4
# ProductID                67
# Quantity                 29
# Sales                1773.0
# StoreID                   7
# OrderStatus        Complete
# Name: 4827, dtype: object
#
#
# Item number 12
# SalesDate        2021-06-02
# SalesID                 bev
# CustomerID               68
# SalesPersonID             6
# ProductID                13
# Quantity                 47
# Sales                1128.5
# StoreID                   3
# OrderStatus        Complete
# Name: 5593, dtype: object
#
#
# Item number 13
# SalesDate        2021-07-02
# SalesID                UxK8
# CustomerID               42
# SalesPersonID             1
# ProductID                24
# Quantity                 22
# Sales                  88.1
# StoreID                   3
# OrderStatus        Complete
# Name: 6111, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-03
# SalesID          GNyQ9JglFt
# CustomerID               32
# SalesPersonID             1
# ProductID                23
# Quantity                 50
# Sales                 419.0
# StoreID                   9
# OrderStatus        Complete
# Name: 6259, dtype: object
#
#
# Item number 15
# SalesDate        2021-11-02
# SalesID                9qEE
# CustomerID                3
# SalesPersonID             3
# ProductID                75
# Quantity                 29
# Sales                 287.2
# StoreID                   8
# OrderStatus        Complete
# Name: 7997, dtype: object
#
#
# Item number 16
# SalesDate        2021-12-08
# SalesID                 kKR
# CustomerID               37
# SalesPersonID             9
# ProductID                44
# Quantity                 10
# Sales                 854.1
# StoreID                   6
# OrderStatus        Complete
# Name: 8395, dtype: object
#
#
#
#
# SalesID non-complying rows for unique values rule:
# Item number 1
# SalesDate        2020-01-02
# SalesID                 372
# CustomerID               37
# SalesPersonID             2
# ProductID                36
# Quantity                 48
# Sales                 317.1
# StoreID                   2
# OrderStatus        Complete
# Name: 193, dtype: object
#
#
# Item number 2
# SalesDate        2020-01-02
# SalesID                 372
# CustomerID               37
# SalesPersonID             2
# ProductID                36
# Quantity                 48
# Sales                 317.1
# StoreID                   2
# OrderStatus        Complete
# Name: 414, dtype: object
#
#
# Item number 3
# SalesDate        2020-01-14
# SalesID                   6
# CustomerID               19
# SalesPersonID             3
# ProductID                74
# Quantity                 50
# Sales                1360.5
# StoreID                   2
# OrderStatus        Complete
# Name: 404, dtype: object
#
#
# Item number 4
# SalesDate        2021-06-02
# SalesID                   6
# CustomerID               91
# SalesPersonID             8
# ProductID                75
# Quantity                 37
# Sales                 257.9
# StoreID                   2
# OrderStatus        Complete
# Name: 5658, dtype: object
#
#
# Item number 5
# SalesDate        2020-01-17
# SalesID                  28
# CustomerID               37
# SalesPersonID             9
# ProductID                60
# Quantity                 10
# Sales                  51.1
# StoreID                   9
# OrderStatus        Complete
# Name: 427, dtype: object
#
#
# Item number 6
# SalesDate        2020-01-17
# SalesID                  28
# CustomerID               37
# SalesPersonID             9
# ProductID                60
# Quantity                 10
# Sales                  51.1
# StoreID                   9
# OrderStatus        Complete
# Name: 537, dtype: object
#
#
# Item number 7
# SalesDate        2020-06-01
# SalesID                1502
# CustomerID               21
# SalesPersonID             3
# ProductID                19
# Quantity                 17
# Sales                 176.1
# StoreID                   8
# OrderStatus        Complete
# Name: 1450, dtype: object
#
#
# Item number 8
# SalesDate        2020-06-01
# SalesID                1502
# CustomerID               21
# SalesPersonID             3
# ProductID                19
# Quantity                 17
# Sales                 176.1
# StoreID                   8
# OrderStatus        Complete
# Name: 1695, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-17
# SalesID                2904
# CustomerID               44
# SalesPersonID             7
# ProductID                52
# Quantity                  8
# Sales                 683.5
# StoreID                   2
# OrderStatus        Complete
# Name: 3165, dtype: object
#
#
# Item number 10
# SalesDate        2021-01-17
# SalesID                2904
# CustomerID               44
# SalesPersonID             7
# ProductID                52
# Quantity                  8
# Sales                 683.5
# StoreID                   2
# OrderStatus        Complete
# Name: 6644, dtype: object
#
#
#
#
# SalesID non-complying rows for Integer type rule:
# Item number 1
# SalesDate        2020-02-02
# SalesID                   y
# CustomerID               79
# SalesPersonID             7
# ProductID                52
# Quantity                 23
# Sales                1702.3
# StoreID                   9
# OrderStatus        Complete
# Name: 597, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-10
# SalesID                  FH
# CustomerID                5
# SalesPersonID             2
# ProductID                73
# Quantity                 27
# Sales                  29.1
# StoreID                   4
# OrderStatus        Complete
# Name: 676, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-03
# SalesID                   Q
# CustomerID               44
# SalesPersonID             8
# ProductID                30
# Quantity                 15
# Sales                 488.3
# StoreID                   3
# OrderStatus        Complete
# Name: 970, dtype: object
#
#
# Item number 4
# SalesDate        2020-08-28
# SalesID               4Uipa
# CustomerID               37
# SalesPersonID             9
# ProductID                30
# Quantity                 44
# Sales                1130.4
# StoreID                   5
# OrderStatus        Complete
# Name: 2030, dtype: object
#
#
# Item number 5
# SalesDate        2020-09-09
# SalesID            7Uk9tk44
# CustomerID               19
# SalesPersonID             9
# ProductID                35
# Quantity                 33
# Sales                 230.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2128, dtype: object
#
#
# Item number 6
# SalesDate        2021-01-02
# SalesID                   v
# CustomerID               32
# SalesPersonID             1
# ProductID                 1
# Quantity                 36
# Sales                 665.6
# StoreID                   5
# OrderStatus        Complete
# Name: 2719, dtype: object
#
#
# Item number 7
# SalesDate             2021-02-01
# SalesID          yFq2zNd0oKIwNKx
# CustomerID                    48
# SalesPersonID                  1
# ProductID                     76
# Quantity                      10
# Sales                     4000.6
# StoreID                        1
# OrderStatus             Complete
# Name: 3351, dtype: object
#
#
# Item number 8
# SalesDate        2021-02-09
# SalesID                  qD
# CustomerID               63
# SalesPersonID             7
# ProductID                74
# Quantity                 17
# Sales                 634.9
# StoreID                   8
# OrderStatus        Complete
# Name: 3637, dtype: object
#
#
# Item number 9
# SalesDate        2021-03-02
# SalesID            D6LEy6eD
# CustomerID               73
# SalesPersonID             9
# ProductID                56
# Quantity                 29
# Sales                1127.5
# StoreID                   3
# OrderStatus        Complete
# Name: 3873, dtype: object
#
#
# Item number 10
# SalesDate        2021-04-07
# SalesID               BO5wH
# CustomerID               17
# SalesPersonID             8
# ProductID                26
# Quantity                 12
# Sales                 342.6
# StoreID                   5
# OrderStatus        Complete
# Name: 4689, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-19
# SalesID          g1UQTsSvUk
# CustomerID               41
# SalesPersonID             4
# ProductID                67
# Quantity                 29
# Sales                1773.0
# StoreID                   7
# OrderStatus        Complete
# Name: 4827, dtype: object
#
#
# Item number 12
# SalesDate        2021-06-02
# SalesID                 bev
# CustomerID               68
# SalesPersonID             6
# ProductID                13
# Quantity                 47
# Sales                1128.5
# StoreID                   3
# OrderStatus        Complete
# Name: 5593, dtype: object
#
#
# Item number 13
# SalesDate        2021-07-02
# SalesID                UxK8
# CustomerID               42
# SalesPersonID             1
# ProductID                24
# Quantity                 22
# Sales                  88.1
# StoreID                   3
# OrderStatus        Complete
# Name: 6111, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-03
# SalesID          GNyQ9JglFt
# CustomerID               32
# SalesPersonID             1
# ProductID                23
# Quantity                 50
# Sales                 419.0
# StoreID                   9
# OrderStatus        Complete
# Name: 6259, dtype: object
#
#
# Item number 15
# SalesDate        2021-11-02
# SalesID                9qEE
# CustomerID                3
# SalesPersonID             3
# ProductID                75
# Quantity                 29
# Sales                 287.2
# StoreID                   8
# OrderStatus        Complete
# Name: 7997, dtype: object
#
#
# Item number 16
# SalesDate        2021-12-08
# SalesID                 kKR
# CustomerID               37
# SalesPersonID             9
# ProductID                44
# Quantity                 10
# Sales                 854.1
# StoreID                   6
# OrderStatus        Complete
# Name: 8395, dtype: object
#
#
#
#
# Accuracy checks:
# ======
# SalesID non-complying rows for > 0 rule:
# Item number 1
# SalesDate        2020-02-02
# SalesID                   y
# CustomerID               79
# SalesPersonID             7
# ProductID                52
# Quantity                 23
# Sales                1702.3
# StoreID                   9
# OrderStatus        Complete
# Name: 597, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-10
# SalesID                  FH
# CustomerID                5
# SalesPersonID             2
# ProductID                73
# Quantity                 27
# Sales                  29.1
# StoreID                   4
# OrderStatus        Complete
# Name: 676, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-03
# SalesID                   Q
# CustomerID               44
# SalesPersonID             8
# ProductID                30
# Quantity                 15
# Sales                 488.3
# StoreID                   3
# OrderStatus        Complete
# Name: 970, dtype: object
#
#
# Item number 4
# SalesDate        2020-08-28
# SalesID               4Uipa
# CustomerID               37
# SalesPersonID             9
# ProductID                30
# Quantity                 44
# Sales                1130.4
# StoreID                   5
# OrderStatus        Complete
# Name: 2030, dtype: object
#
#
# Item number 5
# SalesDate        2020-09-09
# SalesID            7Uk9tk44
# CustomerID               19
# SalesPersonID             9
# ProductID                35
# Quantity                 33
# Sales                 230.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2128, dtype: object
#
#
# Item number 6
# SalesDate        2021-01-02
# SalesID                   v
# CustomerID               32
# SalesPersonID             1
# ProductID                 1
# Quantity                 36
# Sales                 665.6
# StoreID                   5
# OrderStatus        Complete
# Name: 2719, dtype: object
#
#
# Item number 7
# SalesDate             2021-02-01
# SalesID          yFq2zNd0oKIwNKx
# CustomerID                    48
# SalesPersonID                  1
# ProductID                     76
# Quantity                      10
# Sales                     4000.6
# StoreID                        1
# OrderStatus             Complete
# Name: 3351, dtype: object
#
#
# Item number 8
# SalesDate        2021-02-09
# SalesID                  qD
# CustomerID               63
# SalesPersonID             7
# ProductID                74
# Quantity                 17
# Sales                 634.9
# StoreID                   8
# OrderStatus        Complete
# Name: 3637, dtype: object
#
#
# Item number 9
# SalesDate        2021-03-02
# SalesID            D6LEy6eD
# CustomerID               73
# SalesPersonID             9
# ProductID                56
# Quantity                 29
# Sales                1127.5
# StoreID                   3
# OrderStatus        Complete
# Name: 3873, dtype: object
#
#
# Item number 10
# SalesDate        2021-04-07
# SalesID               BO5wH
# CustomerID               17
# SalesPersonID             8
# ProductID                26
# Quantity                 12
# Sales                 342.6
# StoreID                   5
# OrderStatus        Complete
# Name: 4689, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-19
# SalesID          g1UQTsSvUk
# CustomerID               41
# SalesPersonID             4
# ProductID                67
# Quantity                 29
# Sales                1773.0
# StoreID                   7
# OrderStatus        Complete
# Name: 4827, dtype: object
#
#
# Item number 12
# SalesDate        2021-06-02
# SalesID                 bev
# CustomerID               68
# SalesPersonID             6
# ProductID                13
# Quantity                 47
# Sales                1128.5
# StoreID                   3
# OrderStatus        Complete
# Name: 5593, dtype: object
#
#
# Item number 13
# SalesDate        2021-07-02
# SalesID                UxK8
# CustomerID               42
# SalesPersonID             1
# ProductID                24
# Quantity                 22
# Sales                  88.1
# StoreID                   3
# OrderStatus        Complete
# Name: 6111, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-03
# SalesID          GNyQ9JglFt
# CustomerID               32
# SalesPersonID             1
# ProductID                23
# Quantity                 50
# Sales                 419.0
# StoreID                   9
# OrderStatus        Complete
# Name: 6259, dtype: object
#
#
# Item number 15
# SalesDate        2021-11-02
# SalesID                9qEE
# CustomerID                3
# SalesPersonID             3
# ProductID                75
# Quantity                 29
# Sales                 287.2
# StoreID                   8
# OrderStatus        Complete
# Name: 7997, dtype: object
#
#
# Item number 16
# SalesDate        2021-12-08
# SalesID                 kKR
# CustomerID               37
# SalesPersonID             9
# ProductID                44
# Quantity                 10
# Sales                 854.1
# StoreID                   6
# OrderStatus        Complete
# Name: 8395, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for each rule:

# %%
print('Consistency checks:')
print('======')
print('SalesID percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'SalesID', 'N', [4])))

print('SalesID percentage non-compliance for unique values rule: ' + str(unique_values_percentage_non_compliance(df, 'SalesID')))

print('SalesID percentage non-compliance for Integer type rule: ' + str(data_type_percentage_non_compliance(df, 'SalesID', int)))
print('\n')

print('Accuracy checks:')
print('======')
print('SalesID percentage non-compliance for > 0 rule: ' + str(numerical_range_percentage_non_compliance(df, 'SalesID', lower_bound = 0)))
# Out:
# Consistency checks:
# ======
# SalesID percentage non-compliance for data format: 0.18827959519887033
# SalesID percentage non-compliance for unique values rule: 0.11767474699929395
# SalesID percentage non-compliance for Integer type rule: 0.18827959519887033
#
#
# Accuracy checks:
# ======
# SalesID percentage non-compliance for > 0 rule: 0.18827959519887033

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
sales_id_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'SalesID', 'N', [4]) + unique_values_percentage_non_compliance(df, 'SalesID') + data_type_percentage_non_compliance(df, 'SalesID', int)) / 3
print('Consistency score: ' + str(sales_id_consistency_score))

sales_id_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'SalesID', lower_bound = 0)
print('Accuracy score: ' + str(sales_id_accuracy_score))
# Out:
# Consistency score: 99.83525535420098
# Accuracy score: 99.81172040480114

# %% [markdown]
# ### Move on to validation checks for CustomerID column
# #### Identify rows in CustomerID column that do not comply with **Consistency** and **Accuracy** rules

# %%
print('Consistency checks:')
print('======')
print('CustomerID non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'CustomerID', 'N', [3]))
print('\n')

print('CustomerID non-complying rows for Integer type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'CustomerID', int))
print('\n')

print('Accuracy checks:')
print('======')
print('CustomerID non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'CustomerID', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# CustomerID non-complying rows for data format:
# Item number 1
# SalesDate        2020-01-31
# SalesID                 109
# CustomerID         ielXvjMk
# SalesPersonID             3
# ProductID                53
# Quantity                 46
# Sales                3490.3
# StoreID                   1
# OrderStatus        Complete
# Name: 508, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-25
# SalesID                 131
# CustomerID        QsdorcuT5
# SalesPersonID             3
# ProductID                69
# Quantity                 22
# Sales                  44.7
# StoreID                   8
# OrderStatus        Complete
# Name: 743, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-01
# SalesID                 819
# CustomerID                u
# SalesPersonID             2
# ProductID                26
# Quantity                 30
# Sales                 955.8
# StoreID                   1
# OrderStatus        Complete
# Name: 764, dtype: object
#
#
# Item number 4
# SalesDate        2020-05-10
# SalesID                1439
# CustomerID                J
# SalesPersonID             2
# ProductID                49
# Quantity                 25
# Sales                 491.4
# StoreID                   3
# OrderStatus        Complete
# Name: 1403, dtype: object
#
#
# Item number 5
# SalesDate              2020-05-27
# SalesID                      1287
# CustomerID       ZMI1wTiuYavT1Lhm
# SalesPersonID                   7
# ProductID                      31
# Quantity                       20
# Sales                       171.6
# StoreID                         6
# OrderStatus              Complete
# Name: 1441, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-03
# SalesID                1983
# CustomerID               1N
# SalesPersonID             1
# ProductID                68
# Quantity                 21
# Sales                 339.9
# StoreID                   4
# OrderStatus        Complete
# Name: 1948, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2251
# CustomerID                m
# SalesPersonID             8
# ProductID                25
# Quantity                 50
# Sales                 837.5
# StoreID                   6
# OrderStatus        Complete
# Name: 2254, dtype: object
#
#
# Item number 8
# SalesDate        2020-11-03
# SalesID                2302
# CustomerID           QrUust
# SalesPersonID             3
# ProductID                 5
# Quantity                 26
# Sales                 143.2
# StoreID                   4
# OrderStatus        Complete
# Name: 2305, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-02
# SalesID                3275
# CustomerID         H0PE13K5
# SalesPersonID             1
# ProductID                59
# Quantity                 33
# Sales                 348.5
# StoreID                   7
# OrderStatus        Complete
# Name: 2621, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-25
# SalesID                2470
# CustomerID               Up
# SalesPersonID             3
# ProductID                58
# Quantity                 43
# Sales                2711.8
# StoreID                   7
# OrderStatus        Complete
# Name: 3711, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-01
# SalesID                4717
# CustomerID              IPy
# SalesPersonID             7
# ProductID                76
# Quantity                 25
# Sales                9378.3
# StoreID                   4
# OrderStatus        Complete
# Name: 4328, dtype: object
#
#
# Item number 12
# SalesDate        2021-04-02
# SalesID                4936
# CustomerID          hTBVuM1
# SalesPersonID             9
# ProductID                77
# Quantity                 14
# Sales                 193.9
# StoreID                   7
# OrderStatus        Complete
# Name: 4549, dtype: object
#
#
# Item number 13
# SalesDate        2021-05-02
# SalesID                5309
# CustomerID          Egj4AO4
# SalesPersonID             3
# ProductID                16
# Quantity                 55
# Sales                 552.8
# StoreID                   4
# OrderStatus        Complete
# Name: 5014, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-01
# SalesID                6209
# CustomerID              2kL
# SalesPersonID             5
# ProductID                46
# Quantity                  6
# Sales                  83.6
# StoreID                   4
# OrderStatus        Complete
# Name: 5988, dtype: object
#
#
# Item number 15
# SalesDate        2021-09-01
# SalesID                7375
# CustomerID        yFKyBGMZz
# SalesPersonID             7
# ProductID                 1
# Quantity                 17
# Sales                 292.8
# StoreID                   8
# OrderStatus        Complete
# Name: 7231, dtype: object
#
#
# Item number 16
# SalesDate        2021-09-08
# SalesID                7772
# CustomerID       2SwVSmdWzJ
# SalesPersonID             8
# ProductID                38
# Quantity                 61
# Sales                5164.6
# StoreID                   7
# OrderStatus        Complete
# Name: 7628, dtype: object
#
#
# Item number 17
# SalesDate        2021-12-06
# SalesID                8393
# CustomerID             iyNk
# SalesPersonID             5
# ProductID                33
# Quantity                 28
# Sales                 601.9
# StoreID                   8
# OrderStatus        Complete
# Name: 8359, dtype: object
#
#
#
#
# CustomerID non-complying rows for Integer type rule:
# Item number 1
# SalesDate        2020-01-31
# SalesID                 109
# CustomerID         ielXvjMk
# SalesPersonID             3
# ProductID                53
# Quantity                 46
# Sales                3490.3
# StoreID                   1
# OrderStatus        Complete
# Name: 508, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-25
# SalesID                 131
# CustomerID        QsdorcuT5
# SalesPersonID             3
# ProductID                69
# Quantity                 22
# Sales                  44.7
# StoreID                   8
# OrderStatus        Complete
# Name: 743, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-01
# SalesID                 819
# CustomerID                u
# SalesPersonID             2
# ProductID                26
# Quantity                 30
# Sales                 955.8
# StoreID                   1
# OrderStatus        Complete
# Name: 764, dtype: object
#
#
# Item number 4
# SalesDate        2020-05-10
# SalesID                1439
# CustomerID                J
# SalesPersonID             2
# ProductID                49
# Quantity                 25
# Sales                 491.4
# StoreID                   3
# OrderStatus        Complete
# Name: 1403, dtype: object
#
#
# Item number 5
# SalesDate              2020-05-27
# SalesID                      1287
# CustomerID       ZMI1wTiuYavT1Lhm
# SalesPersonID                   7
# ProductID                      31
# Quantity                       20
# Sales                       171.6
# StoreID                         6
# OrderStatus              Complete
# Name: 1441, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-03
# SalesID                1983
# CustomerID               1N
# SalesPersonID             1
# ProductID                68
# Quantity                 21
# Sales                 339.9
# StoreID                   4
# OrderStatus        Complete
# Name: 1948, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2251
# CustomerID                m
# SalesPersonID             8
# ProductID                25
# Quantity                 50
# Sales                 837.5
# StoreID                   6
# OrderStatus        Complete
# Name: 2254, dtype: object
#
#
# Item number 8
# SalesDate        2020-11-03
# SalesID                2302
# CustomerID           QrUust
# SalesPersonID             3
# ProductID                 5
# Quantity                 26
# Sales                 143.2
# StoreID                   4
# OrderStatus        Complete
# Name: 2305, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-02
# SalesID                3275
# CustomerID         H0PE13K5
# SalesPersonID             1
# ProductID                59
# Quantity                 33
# Sales                 348.5
# StoreID                   7
# OrderStatus        Complete
# Name: 2621, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-25
# SalesID                2470
# CustomerID               Up
# SalesPersonID             3
# ProductID                58
# Quantity                 43
# Sales                2711.8
# StoreID                   7
# OrderStatus        Complete
# Name: 3711, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-01
# SalesID                4717
# CustomerID              IPy
# SalesPersonID             7
# ProductID                76
# Quantity                 25
# Sales                9378.3
# StoreID                   4
# OrderStatus        Complete
# Name: 4328, dtype: object
#
#
# Item number 12
# SalesDate        2021-04-02
# SalesID                4936
# CustomerID          hTBVuM1
# SalesPersonID             9
# ProductID                77
# Quantity                 14
# Sales                 193.9
# StoreID                   7
# OrderStatus        Complete
# Name: 4549, dtype: object
#
#
# Item number 13
# SalesDate        2021-05-02
# SalesID                5309
# CustomerID          Egj4AO4
# SalesPersonID             3
# ProductID                16
# Quantity                 55
# Sales                 552.8
# StoreID                   4
# OrderStatus        Complete
# Name: 5014, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-01
# SalesID                6209
# CustomerID              2kL
# SalesPersonID             5
# ProductID                46
# Quantity                  6
# Sales                  83.6
# StoreID                   4
# OrderStatus        Complete
# Name: 5988, dtype: object
#
#
# Item number 15
# SalesDate        2021-09-01
# SalesID                7375
# CustomerID        yFKyBGMZz
# SalesPersonID             7
# ProductID                 1
# Quantity                 17
# Sales                 292.8
# StoreID                   8
# OrderStatus        Complete
# Name: 7231, dtype: object
#
#
# Item number 16
# SalesDate        2021-09-08
# SalesID                7772
# CustomerID       2SwVSmdWzJ
# SalesPersonID             8
# ProductID                38
# Quantity                 61
# Sales                5164.6
# StoreID                   7
# OrderStatus        Complete
# Name: 7628, dtype: object
#
#
# Item number 17
# SalesDate        2021-12-06
# SalesID                8393
# CustomerID             iyNk
# SalesPersonID             5
# ProductID                33
# Quantity                 28
# Sales                 601.9
# StoreID                   8
# OrderStatus        Complete
# Name: 8359, dtype: object
#
#
#
#
# Accuracy checks:
# ======
# CustomerID non-complying rows for > 0 rule:
# Item number 1
# SalesDate        2020-01-31
# SalesID                 109
# CustomerID         ielXvjMk
# SalesPersonID             3
# ProductID                53
# Quantity                 46
# Sales                3490.3
# StoreID                   1
# OrderStatus        Complete
# Name: 508, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-25
# SalesID                 131
# CustomerID        QsdorcuT5
# SalesPersonID             3
# ProductID                69
# Quantity                 22
# Sales                  44.7
# StoreID                   8
# OrderStatus        Complete
# Name: 743, dtype: object
#
#
# Item number 3
# SalesDate        2020-03-01
# SalesID                 819
# CustomerID                u
# SalesPersonID             2
# ProductID                26
# Quantity                 30
# Sales                 955.8
# StoreID                   1
# OrderStatus        Complete
# Name: 764, dtype: object
#
#
# Item number 4
# SalesDate        2020-05-10
# SalesID                1439
# CustomerID                J
# SalesPersonID             2
# ProductID                49
# Quantity                 25
# Sales                 491.4
# StoreID                   3
# OrderStatus        Complete
# Name: 1403, dtype: object
#
#
# Item number 5
# SalesDate              2020-05-27
# SalesID                      1287
# CustomerID       ZMI1wTiuYavT1Lhm
# SalesPersonID                   7
# ProductID                      31
# Quantity                       20
# Sales                       171.6
# StoreID                         6
# OrderStatus              Complete
# Name: 1441, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-03
# SalesID                1983
# CustomerID               1N
# SalesPersonID             1
# ProductID                68
# Quantity                 21
# Sales                 339.9
# StoreID                   4
# OrderStatus        Complete
# Name: 1948, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2251
# CustomerID                m
# SalesPersonID             8
# ProductID                25
# Quantity                 50
# Sales                 837.5
# StoreID                   6
# OrderStatus        Complete
# Name: 2254, dtype: object
#
#
# Item number 8
# SalesDate        2020-11-03
# SalesID                2302
# CustomerID           QrUust
# SalesPersonID             3
# ProductID                 5
# Quantity                 26
# Sales                 143.2
# StoreID                   4
# OrderStatus        Complete
# Name: 2305, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-02
# SalesID                3275
# CustomerID         H0PE13K5
# SalesPersonID             1
# ProductID                59
# Quantity                 33
# Sales                 348.5
# StoreID                   7
# OrderStatus        Complete
# Name: 2621, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-25
# SalesID                2470
# CustomerID               Up
# SalesPersonID             3
# ProductID                58
# Quantity                 43
# Sales                2711.8
# StoreID                   7
# OrderStatus        Complete
# Name: 3711, dtype: object
#
#
# Item number 11
# SalesDate        2021-04-01
# SalesID                4717
# CustomerID              IPy
# SalesPersonID             7
# ProductID                76
# Quantity                 25
# Sales                9378.3
# StoreID                   4
# OrderStatus        Complete
# Name: 4328, dtype: object
#
#
# Item number 12
# SalesDate        2021-04-02
# SalesID                4936
# CustomerID          hTBVuM1
# SalesPersonID             9
# ProductID                77
# Quantity                 14
# Sales                 193.9
# StoreID                   7
# OrderStatus        Complete
# Name: 4549, dtype: object
#
#
# Item number 13
# SalesDate        2021-05-02
# SalesID                5309
# CustomerID          Egj4AO4
# SalesPersonID             3
# ProductID                16
# Quantity                 55
# Sales                 552.8
# StoreID                   4
# OrderStatus        Complete
# Name: 5014, dtype: object
#
#
# Item number 14
# SalesDate        2021-07-01
# SalesID                6209
# CustomerID              2kL
# SalesPersonID             5
# ProductID                46
# Quantity                  6
# Sales                  83.6
# StoreID                   4
# OrderStatus        Complete
# Name: 5988, dtype: object
#
#
# Item number 15
# SalesDate        2021-09-01
# SalesID                7375
# CustomerID        yFKyBGMZz
# SalesPersonID             7
# ProductID                 1
# Quantity                 17
# Sales                 292.8
# StoreID                   8
# OrderStatus        Complete
# Name: 7231, dtype: object
#
#
# Item number 16
# SalesDate        2021-09-08
# SalesID                7772
# CustomerID       2SwVSmdWzJ
# SalesPersonID             8
# ProductID                38
# Quantity                 61
# Sales                5164.6
# StoreID                   7
# OrderStatus        Complete
# Name: 7628, dtype: object
#
#
# Item number 17
# SalesDate        2021-12-06
# SalesID                8393
# CustomerID             iyNk
# SalesPersonID             5
# ProductID                33
# Quantity                 28
# Sales                 601.9
# StoreID                   8
# OrderStatus        Complete
# Name: 8359, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for each rule:

# %%
print('Consistency checks:')
print('======')
print('CustomerID percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'CustomerID', 'N', [3])))

print('CustomerID percentage non-compliance for Integer type rule: ' + str(data_type_percentage_non_compliance(df, 'CustomerID', int)))
print('\n')

print('Accuracy checks:')
print('======')
print('CustomerID percentage non-compliance for > 0 rule: ')
print(numerical_range_percentage_non_compliance(df, 'CustomerID', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# CustomerID percentage non-compliance for data format: 0.20004706989879972
# CustomerID percentage non-compliance for Integer type rule: 0.20004706989879972
#
#
# Accuracy checks:
# ======
# CustomerID percentage non-compliance for > 0 rule:
# 0.20004706989879972

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
customer_id_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'CustomerID', 'N', [3]) + data_type_percentage_non_compliance(df, 'CustomerID', int)) / 2
print('Consistency score: ' + str(customer_id_consistency_score))

customer_id_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'CustomerID', lower_bound = 0)
print('Accuracy score: ' + str(customer_id_accuracy_score))
# Out:
# Consistency score: 99.7999529301012
# Accuracy score: 99.7999529301012

# %% [markdown]
# ### Move on to validation checks for SalesPersonID column
# #### Identify rows in SalesPersonID column that do not comply with **Consistency** and **Accuracy** rules

# %%
print('Consistency checks:')
print('======')
print('SalesPersonID non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'SalesPersonID', 'N', [1]))
print('\n')

print('SalesPersonID non-complying rows for Integer type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'SalesPersonID', int))
print('\n')

print('Accuracy checks:')
print('======')
print('SalesPersonID non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'SalesPersonID', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# SalesPersonID non-complying rows for data format:
# Item number 1
# SalesDate        2020-02-02
# SalesID                 715
# CustomerID               75
# SalesPersonID          NqWS
# ProductID                30
# Quantity                  7
# Sales                 209.2
# StoreID                   7
# OrderStatus        Complete
# Name: 592, dtype: object
#
#
# Item number 2
# SalesDate                       2020-03-02
# SalesID                                968
# CustomerID                              10
# SalesPersonID    xlnqAIbfylfqG82GiTIww3WQQ
# ProductID                               62
# Quantity                                57
# Sales                               1395.4
# StoreID                                  9
# OrderStatus                       Complete
# Name: 913, dtype: object
#
#
# Item number 3
# SalesDate         2020-03-02
# SalesID                 1005
# CustomerID                63
# SalesPersonID    89tT2ASfvMz
# ProductID                 13
# Quantity                  80
# Sales                 2287.3
# StoreID                    4
# OrderStatus         Complete
# Name: 950, dtype: object
#
#
# Item number 4
# SalesDate        2020-03-28
# SalesID                 600
# CustomerID               41
# SalesPersonID             g
# ProductID                36
# Quantity                  6
# Sales                  46.0
# StoreID                   1
# OrderStatus        Complete
# Name: 1064, dtype: object
#
#
# Item number 5
# SalesDate        2020-07-15
# SalesID                1683
# CustomerID               63
# SalesPersonID       SLsAspk
# ProductID                38
# Quantity                 27
# Sales                2705.1
# StoreID                   1
# OrderStatus        Complete
# Name: 1838, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-02
# SalesID                1942
# CustomerID               63
# SalesPersonID             r
# ProductID                35
# Quantity                109
# Sales                 757.5
# StoreID                   4
# OrderStatus        Complete
# Name: 1907, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2252
# CustomerID               44
# SalesPersonID             K
# ProductID                51
# Quantity                 20
# Sales                2445.4
# StoreID                   6
# OrderStatus        Complete
# Name: 2255, dtype: object
#
#
# Item number 8
# SalesDate        2021-01-07
# SalesID                3649
# CustomerID               63
# SalesPersonID            8o
# ProductID                51
# Quantity                 53
# Sales                5224.8
# StoreID                   9
# OrderStatus        Complete
# Name: 3015, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-18
# SalesID                2425
# CustomerID               74
# SalesPersonID       2xxryze
# ProductID                18
# Quantity                  6
# Sales                 152.4
# StoreID                   4
# OrderStatus        Complete
# Name: 3170, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-01
# SalesID                3751
# CustomerID               24
# SalesPersonID          sl4K
# ProductID                62
# Quantity                  6
# Sales                 168.0
# StoreID                   2
# OrderStatus        Complete
# Name: 3270, dtype: object
#
#
# Item number 11
# SalesDate        2021-03-01
# SalesID                4226
# CustomerID               79
# SalesPersonID        23Cnl9
# ProductID                34
# Quantity                 23
# Sales                 187.5
# StoreID                   2
# OrderStatus        Complete
# Name: 3761, dtype: object
#
#
# Item number 12
# SalesDate        2021-03-02
# SalesID                4406
# CustomerID                3
# SalesPersonID           LPh
# ProductID                11
# Quantity                 60
# Sales                1669.4
# StoreID                   3
# OrderStatus        Complete
# Name: 3941, dtype: object
#
#
# Item number 13
# SalesDate        2021-03-08
# SalesID                4549
# CustomerID                5
# SalesPersonID          OoSf
# ProductID                39
# Quantity                 19
# Sales                1369.2
# StoreID                   4
# OrderStatus        Complete
# Name: 4084, dtype: object
#
#
# Item number 14
# SalesDate        2021-04-06
# SalesID                5061
# CustomerID               37
# SalesPersonID            Bi
# ProductID                 4
# Quantity                 18
# Sales                 343.6
# StoreID                   3
# OrderStatus        Complete
# Name: 4682, dtype: object
#
#
# Item number 15
# SalesDate        2021-04-09
# SalesID                5091
# CustomerID               17
# SalesPersonID            qO
# ProductID                22
# Quantity                 59
# Sales                 177.6
# StoreID                   9
# OrderStatus        Complete
# Name: 4718, dtype: object
#
#
# Item number 16
# SalesDate        2021-05-01
# SalesID                5184
# CustomerID                9
# SalesPersonID             X
# ProductID                19
# Quantity                 10
# Sales                  97.8
# StoreID                   6
# OrderStatus        Complete
# Name: 4889, dtype: object
#
#
#
#
# SalesPersonID non-complying rows for Integer type rule:
# Item number 1
# SalesDate        2020-02-02
# SalesID                 715
# CustomerID               75
# SalesPersonID          NqWS
# ProductID                30
# Quantity                  7
# Sales                 209.2
# StoreID                   7
# OrderStatus        Complete
# Name: 592, dtype: object
#
#
# Item number 2
# SalesDate                       2020-03-02
# SalesID                                968
# CustomerID                              10
# SalesPersonID    xlnqAIbfylfqG82GiTIww3WQQ
# ProductID                               62
# Quantity                                57
# Sales                               1395.4
# StoreID                                  9
# OrderStatus                       Complete
# Name: 913, dtype: object
#
#
# Item number 3
# SalesDate         2020-03-02
# SalesID                 1005
# CustomerID                63
# SalesPersonID    89tT2ASfvMz
# ProductID                 13
# Quantity                  80
# Sales                 2287.3
# StoreID                    4
# OrderStatus         Complete
# Name: 950, dtype: object
#
#
# Item number 4
# SalesDate        2020-03-28
# SalesID                 600
# CustomerID               41
# SalesPersonID             g
# ProductID                36
# Quantity                  6
# Sales                  46.0
# StoreID                   1
# OrderStatus        Complete
# Name: 1064, dtype: object
#
#
# Item number 5
# SalesDate        2020-07-15
# SalesID                1683
# CustomerID               63
# SalesPersonID       SLsAspk
# ProductID                38
# Quantity                 27
# Sales                2705.1
# StoreID                   1
# OrderStatus        Complete
# Name: 1838, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-02
# SalesID                1942
# CustomerID               63
# SalesPersonID             r
# ProductID                35
# Quantity                109
# Sales                 757.5
# StoreID                   4
# OrderStatus        Complete
# Name: 1907, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2252
# CustomerID               44
# SalesPersonID             K
# ProductID                51
# Quantity                 20
# Sales                2445.4
# StoreID                   6
# OrderStatus        Complete
# Name: 2255, dtype: object
#
#
# Item number 8
# SalesDate        2021-01-07
# SalesID                3649
# CustomerID               63
# SalesPersonID            8o
# ProductID                51
# Quantity                 53
# Sales                5224.8
# StoreID                   9
# OrderStatus        Complete
# Name: 3015, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-18
# SalesID                2425
# CustomerID               74
# SalesPersonID       2xxryze
# ProductID                18
# Quantity                  6
# Sales                 152.4
# StoreID                   4
# OrderStatus        Complete
# Name: 3170, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-01
# SalesID                3751
# CustomerID               24
# SalesPersonID          sl4K
# ProductID                62
# Quantity                  6
# Sales                 168.0
# StoreID                   2
# OrderStatus        Complete
# Name: 3270, dtype: object
#
#
# Item number 11
# SalesDate        2021-03-01
# SalesID                4226
# CustomerID               79
# SalesPersonID        23Cnl9
# ProductID                34
# Quantity                 23
# Sales                 187.5
# StoreID                   2
# OrderStatus        Complete
# Name: 3761, dtype: object
#
#
# Item number 12
# SalesDate        2021-03-02
# SalesID                4406
# CustomerID                3
# SalesPersonID           LPh
# ProductID                11
# Quantity                 60
# Sales                1669.4
# StoreID                   3
# OrderStatus        Complete
# Name: 3941, dtype: object
#
#
# Item number 13
# SalesDate        2021-03-08
# SalesID                4549
# CustomerID                5
# SalesPersonID          OoSf
# ProductID                39
# Quantity                 19
# Sales                1369.2
# StoreID                   4
# OrderStatus        Complete
# Name: 4084, dtype: object
#
#
# Item number 14
# SalesDate        2021-04-06
# SalesID                5061
# CustomerID               37
# SalesPersonID            Bi
# ProductID                 4
# Quantity                 18
# Sales                 343.6
# StoreID                   3
# OrderStatus        Complete
# Name: 4682, dtype: object
#
#
# Item number 15
# SalesDate        2021-04-09
# SalesID                5091
# CustomerID               17
# SalesPersonID            qO
# ProductID                22
# Quantity                 59
# Sales                 177.6
# StoreID                   9
# OrderStatus        Complete
# Name: 4718, dtype: object
#
#
# Item number 16
# SalesDate        2021-05-01
# SalesID                5184
# CustomerID                9
# SalesPersonID             X
# ProductID                19
# Quantity                 10
# Sales                  97.8
# StoreID                   6
# OrderStatus        Complete
# Name: 4889, dtype: object
#
#
#
#
# Accuracy checks:
# ======
# SalesPersonID non-complying rows for > 0 rule:
# Item number 1
# SalesDate        2020-02-02
# SalesID                 715
# CustomerID               75
# SalesPersonID          NqWS
# ProductID                30
# Quantity                  7
# Sales                 209.2
# StoreID                   7
# OrderStatus        Complete
# Name: 592, dtype: object
#
#
# Item number 2
# SalesDate                       2020-03-02
# SalesID                                968
# CustomerID                              10
# SalesPersonID    xlnqAIbfylfqG82GiTIww3WQQ
# ProductID                               62
# Quantity                                57
# Sales                               1395.4
# StoreID                                  9
# OrderStatus                       Complete
# Name: 913, dtype: object
#
#
# Item number 3
# SalesDate         2020-03-02
# SalesID                 1005
# CustomerID                63
# SalesPersonID    89tT2ASfvMz
# ProductID                 13
# Quantity                  80
# Sales                 2287.3
# StoreID                    4
# OrderStatus         Complete
# Name: 950, dtype: object
#
#
# Item number 4
# SalesDate        2020-03-28
# SalesID                 600
# CustomerID               41
# SalesPersonID             g
# ProductID                36
# Quantity                  6
# Sales                  46.0
# StoreID                   1
# OrderStatus        Complete
# Name: 1064, dtype: object
#
#
# Item number 5
# SalesDate        2020-07-15
# SalesID                1683
# CustomerID               63
# SalesPersonID       SLsAspk
# ProductID                38
# Quantity                 27
# Sales                2705.1
# StoreID                   1
# OrderStatus        Complete
# Name: 1838, dtype: object
#
#
# Item number 6
# SalesDate        2020-08-02
# SalesID                1942
# CustomerID               63
# SalesPersonID             r
# ProductID                35
# Quantity                109
# Sales                 757.5
# StoreID                   4
# OrderStatus        Complete
# Name: 1907, dtype: object
#
#
# Item number 7
# SalesDate        2020-10-04
# SalesID                2252
# CustomerID               44
# SalesPersonID             K
# ProductID                51
# Quantity                 20
# Sales                2445.4
# StoreID                   6
# OrderStatus        Complete
# Name: 2255, dtype: object
#
#
# Item number 8
# SalesDate        2021-01-07
# SalesID                3649
# CustomerID               63
# SalesPersonID            8o
# ProductID                51
# Quantity                 53
# Sales                5224.8
# StoreID                   9
# OrderStatus        Complete
# Name: 3015, dtype: object
#
#
# Item number 9
# SalesDate        2021-01-18
# SalesID                2425
# CustomerID               74
# SalesPersonID       2xxryze
# ProductID                18
# Quantity                  6
# Sales                 152.4
# StoreID                   4
# OrderStatus        Complete
# Name: 3170, dtype: object
#
#
# Item number 10
# SalesDate        2021-02-01
# SalesID                3751
# CustomerID               24
# SalesPersonID          sl4K
# ProductID                62
# Quantity                  6
# Sales                 168.0
# StoreID                   2
# OrderStatus        Complete
# Name: 3270, dtype: object
#
#
# Item number 11
# SalesDate        2021-03-01
# SalesID                4226
# CustomerID               79
# SalesPersonID        23Cnl9
# ProductID                34
# Quantity                 23
# Sales                 187.5
# StoreID                   2
# OrderStatus        Complete
# Name: 3761, dtype: object
#
#
# Item number 12
# SalesDate        2021-03-02
# SalesID                4406
# CustomerID                3
# SalesPersonID           LPh
# ProductID                11
# Quantity                 60
# Sales                1669.4
# StoreID                   3
# OrderStatus        Complete
# Name: 3941, dtype: object
#
#
# Item number 13
# SalesDate        2021-03-08
# SalesID                4549
# CustomerID                5
# SalesPersonID          OoSf
# ProductID                39
# Quantity                 19
# Sales                1369.2
# StoreID                   4
# OrderStatus        Complete
# Name: 4084, dtype: object
#
#
# Item number 14
# SalesDate        2021-04-06
# SalesID                5061
# CustomerID               37
# SalesPersonID            Bi
# ProductID                 4
# Quantity                 18
# Sales                 343.6
# StoreID                   3
# OrderStatus        Complete
# Name: 4682, dtype: object
#
#
# Item number 15
# SalesDate        2021-04-09
# SalesID                5091
# CustomerID               17
# SalesPersonID            qO
# ProductID                22
# Quantity                 59
# Sales                 177.6
# StoreID                   9
# OrderStatus        Complete
# Name: 4718, dtype: object
#
#
# Item number 16
# SalesDate        2021-05-01
# SalesID                5184
# CustomerID                9
# SalesPersonID             X
# ProductID                19
# Quantity                 10
# Sales                  97.8
# StoreID                   6
# OrderStatus        Complete
# Name: 4889, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for each rule:

# %%
print('Consistency checks:')
print('======')
print('SalesPersonID percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'SalesPersonID', 'N', [1])))

print('SalesPersonID percentage non-compliance for Integer type rule: ' + str(data_type_percentage_non_compliance(df, 'SalesPersonID', int)))
print('\n')

print('Accuracy checks:')
print('======')
print('SalesPersonID percentage non-compliance for > 0 rule: ' + str(numerical_range_percentage_non_compliance(df, 'SalesPersonID', lower_bound = 0)))
# Out:
# Consistency checks:
# ======
# SalesPersonID percentage non-compliance for data format: 0.18827959519887033
# SalesPersonID percentage non-compliance for Integer type rule: 0.18827959519887033
#
#
# Accuracy checks:
# ======
# SalesPersonID percentage non-compliance for > 0 rule: 0.18827959519887033

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
salesperson_id_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'SalesPersonID', 'N', [1]) + data_type_percentage_non_compliance(df, 'SalesPersonID', int)) / 2
print('Consistency score: ' + str(salesperson_id_consistency_score))

salesperson_id_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'SalesPersonID', lower_bound = 0)
print('Accuracy score: ' + str(salesperson_id_accuracy_score))
# Out:
# Consistency score: 99.81172040480114
# Accuracy score: 99.81172040480114

# %% [markdown]
# # Your turn!
# Fill in the code blocks to identify non-complying rows, calculate percentage non-compliance, and calculate **Consistency** and **Accuracy** scores for the ProductID and Quantity columns

# %% [markdown]
# ## Check ProductID column
# Identify rows in ProductID column that do not comply with **Consistency** and **Accuracy** rules:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Run the validation check functions to find non-complying rows ↓↓↓</b>
# </div>

# %%
print('Consistency checks:')
print('======')
print('ProductID non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'ProductID', 'N', [2]))
print('\n')

print('ProductID non-complying rows for Integer type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'ProductID', int))
print('\n')

print('Accuracy checks:')
print('======')
print('ProductID non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'ProductID', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# ProductID non-complying rows for data format:
# Item number 1
# SalesDate        2020-05-02
# SalesID                1362
# CustomerID               28
# SalesPersonID             4
# ProductID               -77
# Quantity                  8
# Sales                 136.2
# StoreID                   3
# OrderStatus        Complete
# Name: 1326, dtype: object
#
#
# Item number 2
# SalesDate                     2020-06-02
# SalesID                             1512
# CustomerID                            59
# SalesPersonID                          4
# ProductID        24j2K5WcBfQH0JpmHDlxsYg
# Quantity                              35
# Sales                              851.6
# StoreID                                7
# OrderStatus                     Complete
# Name: 1460, dtype: object
#
#
# Item number 3
# SalesDate        2020-09-02
# SalesID                2143
# CustomerID               19
# SalesPersonID             3
# ProductID              UHZy
# Quantity                 34
# Sales                1755.6
# StoreID                   7
# OrderStatus        Complete
# Name: 2092, dtype: object
#
#
# Item number 4
# SalesDate        2021-01-02
# SalesID                3388
# CustomerID              127
# SalesPersonID             9
# ProductID         3xgXb3plr
# Quantity                  9
# Sales                  44.3
# StoreID                   7
# OrderStatus        Complete
# Name: 2734, dtype: object
#
#
# Item number 5
# SalesDate        2021-01-03
# SalesID                3526
# CustomerID               34
# SalesPersonID             9
# ProductID               -19
# Quantity                 38
# Sales                 322.8
# StoreID                   4
# OrderStatus        Complete
# Name: 2876, dtype: object
#
#
# Item number 6
# SalesDate        2021-04-02
# SalesID                4909
# CustomerID               35
# SalesPersonID             9
# ProductID                EK
# Quantity                 19
# Sales                1003.9
# StoreID                   1
# OrderStatus        Complete
# Name: 4522, dtype: object
#
#
# Item number 7
# SalesDate        2021-04-16
# SalesID                2515
# CustomerID               51
# SalesPersonID             1
# ProductID               -18
# Quantity                 40
# Sales                1107.1
# StoreID                   8
# OrderStatus        Complete
# Name: 4814, dtype: object
#
#
# Item number 8
# SalesDate        2021-05-09
# SalesID                5610
# CustomerID               47
# SalesPersonID             3
# ProductID                 y
# Quantity                 66
# Sales                1475.1
# StoreID                   5
# OrderStatus        Complete
# Name: 5315, dtype: object
#
#
# Item number 9
# SalesDate        2021-06-01
# SalesID                5755
# CustomerID               32
# SalesPersonID             4
# ProductID               -50
# Quantity                 21
# Sales                 348.8
# StoreID                   6
# OrderStatus        Complete
# Name: 5498, dtype: object
#
#
# Item number 10
# SalesDate        2021-06-01
# SalesID                5778
# CustomerID               37
# SalesPersonID             9
# ProductID                Od
# Quantity                 12
# Sales                  52.6
# StoreID                   9
# OrderStatus        Complete
# Name: 5521, dtype: object
#
#
# Item number 11
# SalesDate        2021-07-01
# SalesID                6145
# CustomerID               30
# SalesPersonID             5
# ProductID               -68
# Quantity                 14
# Sales                 153.7
# StoreID                   9
# OrderStatus        Complete
# Name: 5924, dtype: object
#
#
# Item number 12
# SalesDate                   2021-07-10
# SalesID                           6673
# CustomerID                          32
# SalesPersonID                        1
# ProductID        WhcfHZegdLdCLO49ITICn
# Quantity                            69
# Sales                            342.4
# StoreID                              5
# OrderStatus                   Complete
# Name: 6452, dtype: object
#
#
# Item number 13
# SalesDate        2021-09-02
# SalesID                7587
# CustomerID               38
# SalesPersonID             9
# ProductID               -72
# Quantity                 12
# Sales                 131.8
# StoreID                   4
# OrderStatus        Complete
# Name: 7443, dtype: object
#
#
# Item number 14
# SalesDate        2021-11-17
# SalesID                2813
# CustomerID               31
# SalesPersonID             9
# ProductID               -12
# Quantity                  4
# Sales                  39.6
# StoreID                   5
# OrderStatus        Complete
# Name: 8227, dtype: object
#
#
#
#
# ProductID non-complying rows for Integer type rule:
# Item number 1
# SalesDate                     2020-06-02
# SalesID                             1512
# CustomerID                            59
# SalesPersonID                          4
# ProductID        24j2K5WcBfQH0JpmHDlxsYg
# Quantity                              35
# Sales                              851.6
# StoreID                                7
# OrderStatus                     Complete
# Name: 1460, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-02
# SalesID                2143
# CustomerID               19
# SalesPersonID             3
# ProductID              UHZy
# Quantity                 34
# Sales                1755.6
# StoreID                   7
# OrderStatus        Complete
# Name: 2092, dtype: object
#
#
# Item number 3
# SalesDate        2021-01-02
# SalesID                3388
# CustomerID              127
# SalesPersonID             9
# ProductID         3xgXb3plr
# Quantity                  9
# Sales                  44.3
# StoreID                   7
# OrderStatus        Complete
# Name: 2734, dtype: object
#
#
# Item number 4
# SalesDate        2021-04-02
# SalesID                4909
# CustomerID               35
# SalesPersonID             9
# ProductID                EK
# Quantity                 19
# Sales                1003.9
# StoreID                   1
# OrderStatus        Complete
# Name: 4522, dtype: object
#
#
# Item number 5
# SalesDate        2021-05-09
# SalesID                5610
# CustomerID               47
# SalesPersonID             3
# ProductID                 y
# Quantity                 66
# Sales                1475.1
# StoreID                   5
# OrderStatus        Complete
# Name: 5315, dtype: object
#
#
# Item number 6
# SalesDate        2021-06-01
# SalesID                5778
# CustomerID               37
# SalesPersonID             9
# ProductID                Od
# Quantity                 12
# Sales                  52.6
# StoreID                   9
# OrderStatus        Complete
# Name: 5521, dtype: object
#
#
# Item number 7
# SalesDate                   2021-07-10
# SalesID                           6673
# CustomerID                          32
# SalesPersonID                        1
# ProductID        WhcfHZegdLdCLO49ITICn
# Quantity                            69
# Sales                            342.4
# StoreID                              5
# OrderStatus                   Complete
# Name: 6452, dtype: object
#
#
#
#
# Accuracy checks:
# ======
# ProductID non-complying rows for > 0 rule:
# Item number 1
# SalesDate        2020-05-02
# SalesID                1362
# CustomerID               28
# SalesPersonID             4
# ProductID               -77
# Quantity                  8
# Sales                 136.2
# StoreID                   3
# OrderStatus        Complete
# Name: 1326, dtype: object
#
#
# Item number 2
# SalesDate                     2020-06-02
# SalesID                             1512
# CustomerID                            59
# SalesPersonID                          4
# ProductID        24j2K5WcBfQH0JpmHDlxsYg
# Quantity                              35
# Sales                              851.6
# StoreID                                7
# OrderStatus                     Complete
# Name: 1460, dtype: object
#
#
# Item number 3
# SalesDate        2020-09-02
# SalesID                2143
# CustomerID               19
# SalesPersonID             3
# ProductID              UHZy
# Quantity                 34
# Sales                1755.6
# StoreID                   7
# OrderStatus        Complete
# Name: 2092, dtype: object
#
#
# Item number 4
# SalesDate        2021-01-02
# SalesID                3388
# CustomerID              127
# SalesPersonID             9
# ProductID         3xgXb3plr
# Quantity                  9
# Sales                  44.3
# StoreID                   7
# OrderStatus        Complete
# Name: 2734, dtype: object
#
#
# Item number 5
# SalesDate        2021-01-03
# SalesID                3526
# CustomerID               34
# SalesPersonID             9
# ProductID               -19
# Quantity                 38
# Sales                 322.8
# StoreID                   4
# OrderStatus        Complete
# Name: 2876, dtype: object
#
#
# Item number 6
# SalesDate        2021-04-02
# SalesID                4909
# CustomerID               35
# SalesPersonID             9
# ProductID                EK
# Quantity                 19
# Sales                1003.9
# StoreID                   1
# OrderStatus        Complete
# Name: 4522, dtype: object
#
#
# Item number 7
# SalesDate        2021-04-16
# SalesID                2515
# CustomerID               51
# SalesPersonID             1
# ProductID               -18
# Quantity                 40
# Sales                1107.1
# StoreID                   8
# OrderStatus        Complete
# Name: 4814, dtype: object
#
#
# Item number 8
# SalesDate        2021-05-09
# SalesID                5610
# CustomerID               47
# SalesPersonID             3
# ProductID                 y
# Quantity                 66
# Sales                1475.1
# StoreID                   5
# OrderStatus        Complete
# Name: 5315, dtype: object
#
#
# Item number 9
# SalesDate        2021-06-01
# SalesID                5755
# CustomerID               32
# SalesPersonID             4
# ProductID               -50
# Quantity                 21
# Sales                 348.8
# StoreID                   6
# OrderStatus        Complete
# Name: 5498, dtype: object
#
#
# Item number 10
# SalesDate        2021-06-01
# SalesID                5778
# CustomerID               37
# SalesPersonID             9
# ProductID                Od
# Quantity                 12
# Sales                  52.6
# StoreID                   9
# OrderStatus        Complete
# Name: 5521, dtype: object
#
#
# Item number 11
# SalesDate        2021-07-01
# SalesID                6145
# CustomerID               30
# SalesPersonID             5
# ProductID               -68
# Quantity                 14
# Sales                 153.7
# StoreID                   9
# OrderStatus        Complete
# Name: 5924, dtype: object
#
#
# Item number 12
# SalesDate                   2021-07-10
# SalesID                           6673
# CustomerID                          32
# SalesPersonID                        1
# ProductID        WhcfHZegdLdCLO49ITICn
# Quantity                            69
# Sales                            342.4
# StoreID                              5
# OrderStatus                   Complete
# Name: 6452, dtype: object
#
#
# Item number 13
# SalesDate        2021-09-02
# SalesID                7587
# CustomerID               38
# SalesPersonID             9
# ProductID               -72
# Quantity                 12
# Sales                 131.8
# StoreID                   4
# OrderStatus        Complete
# Name: 7443, dtype: object
#
#
# Item number 14
# SalesDate        2021-11-17
# SalesID                2813
# CustomerID               31
# SalesPersonID             9
# ProductID               -12
# Quantity                  4
# Sales                  39.6
# StoreID                   5
# OrderStatus        Complete
# Name: 8227, dtype: object

# %% [markdown]
# Find percentage non-compliance for each rule:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Run the validation check functions to find percentage non-compliance ↓↓↓</b>
# </div>

# %%
print('Consistency checks:')
print('======')
print('ProductID percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'ProductID', 'N', [2])))

print('ProductID percentage non-compliance for Integer type rule: ' + str(data_type_percentage_non_compliance(df, 'ProductID', int)))
print('\n')

print('Accuracy checks:')
print('======')
print('ProductID percentage non-compliance for > 0 rule: ' + str(numerical_range_percentage_non_compliance(df, 'ProductID', lower_bound = 0)))
# Out:
# Consistency checks:
# ======
# ProductID percentage non-compliance for data format: 0.16474464579901155
# ProductID percentage non-compliance for Integer type rule: 0.08237232289950577
#
#
# Accuracy checks:
# ======
# ProductID percentage non-compliance for > 0 rule: 0.16474464579901155

# %% [markdown]
# Calculate **Consistency** and **Accuracy** scores:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Calculate scores for ProductID column ↓↓↓</b>
# </div>

# %%
product_id_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'ProductID', 'N', [2]) + data_type_percentage_non_compliance(df, 'ProductID', int)) / 2
print('Consistency score: ' + str(product_id_consistency_score))

product_id_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'ProductID', lower_bound = 0)
print('Accuracy score: ' + str(product_id_accuracy_score))
# Out:
# Consistency score: 99.87644151565074
# Accuracy score: 99.83525535420098

# %% [markdown]
# Identify rows in Quantity column that do not comply with **Consistency** and **Accuracy** rules:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Run the validation check functions to find non-complying rows ↓↓↓</b>
# </div>

# %%
print('Consistency checks:')
print('======')
print('Quantity non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'Quantity', 'N', [4]))
print('\n')

print('Quantity non-complying rows for Integer type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'Quantity', int))
print('\n')

print('Accuracy checks:')
print('======')
print(' non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'Quantity', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# Quantity non-complying rows for data format:
# Item number 1
# SalesDate        2020-02-08
# SalesID                 782
# CustomerID               39
# SalesPersonID             3
# ProductID                 6
# Quantity                  e
# Sales                  27.0
# StoreID                   1
# OrderStatus        Complete
# Name: 659, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-12
# SalesID                2211
# CustomerID                5
# SalesPersonID             3
# ProductID                55
# Quantity                  n
# Sales                 849.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2160, dtype: object
#
#
# Item number 3
# SalesDate        2021-02-11
# SalesID                4150
# CustomerID               19
# SalesPersonID             9
# ProductID                21
# Quantity               SoKA
# Sales                 444.1
# StoreID                   1
# OrderStatus        Complete
# Name: 3669, dtype: object
#
#
# Item number 4
# SalesDate            2021-04-01
# SalesID                    4657
# CustomerID                   87
# SalesPersonID                 7
# ProductID                    14
# Quantity         S8dTEimdwH6723
# Sales                     248.7
# StoreID                       3
# OrderStatus            Complete
# Name: 4268, dtype: object
#
#
# Item number 5
# SalesDate        2021-04-01
# SalesID                4689
# CustomerID               19
# SalesPersonID             9
# ProductID                11
# Quantity             KBIEBM
# Sales                 282.8
# StoreID                   3
# OrderStatus        Complete
# Name: 4300, dtype: object
#
#
# Item number 6
# SalesDate             2021-05-01
# SalesID                     5228
# CustomerID                    24
# SalesPersonID                  7
# ProductID                     62
# Quantity         rQgB0KT6os5awe6
# Sales                      156.6
# StoreID                        6
# OrderStatus             Complete
# Name: 4933, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-23
# SalesID                2726
# CustomerID               47
# SalesPersonID             2
# ProductID                45
# Quantity                 UU
# Sales                 168.8
# StoreID                   8
# OrderStatus        Complete
# Name: 5858, dtype: object
#
#
# Item number 8
# SalesDate        2021-07-02
# SalesID                6378
# CustomerID               75
# SalesPersonID             1
# ProductID                68
# Quantity                  O
# Sales                  96.1
# StoreID                   7
# OrderStatus        Complete
# Name: 6157, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-29
# SalesID                2750
# CustomerID               46
# SalesPersonID             2
# ProductID                19
# Quantity                 kN
# Sales                 193.7
# StoreID                   3
# OrderStatus        Complete
# Name: 6527, dtype: object
#
#
# Item number 10
# SalesDate        2021-09-02
# SalesID                7461
# CustomerID               63
# SalesPersonID             8
# ProductID                 6
# Quantity            Z3R536u
# Sales                 180.4
# StoreID                   3
# OrderStatus        Complete
# Name: 7317, dtype: object
#
#
# Item number 11
# SalesDate         2021-12-05
# SalesID                 8366
# CustomerID                82
# SalesPersonID              1
# ProductID                 69
# Quantity         e6BFRUVcWp1
# Sales                   77.4
# StoreID                    3
# OrderStatus         Complete
# Name: 8332, dtype: object
#
#
# Item number 12
# SalesDate                        2021-12-11
# SalesID                                8471
# CustomerID                               66
# SalesPersonID                             6
# ProductID                                68
# Quantity         uAejNBVtIyaeWmnpljmiuOaGMs
# Sales                                  58.1
# StoreID                                   1
# OrderStatus                        Complete
# Name: 8437, dtype: object
#
#
#
#
# Quantity non-complying rows for Integer type rule:
# Item number 1
# SalesDate        2020-02-08
# SalesID                 782
# CustomerID               39
# SalesPersonID             3
# ProductID                 6
# Quantity                  e
# Sales                  27.0
# StoreID                   1
# OrderStatus        Complete
# Name: 659, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-12
# SalesID                2211
# CustomerID                5
# SalesPersonID             3
# ProductID                55
# Quantity                  n
# Sales                 849.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2160, dtype: object
#
#
# Item number 3
# SalesDate        2021-02-11
# SalesID                4150
# CustomerID               19
# SalesPersonID             9
# ProductID                21
# Quantity               SoKA
# Sales                 444.1
# StoreID                   1
# OrderStatus        Complete
# Name: 3669, dtype: object
#
#
# Item number 4
# SalesDate            2021-04-01
# SalesID                    4657
# CustomerID                   87
# SalesPersonID                 7
# ProductID                    14
# Quantity         S8dTEimdwH6723
# Sales                     248.7
# StoreID                       3
# OrderStatus            Complete
# Name: 4268, dtype: object
#
#
# Item number 5
# SalesDate        2021-04-01
# SalesID                4689
# CustomerID               19
# SalesPersonID             9
# ProductID                11
# Quantity             KBIEBM
# Sales                 282.8
# StoreID                   3
# OrderStatus        Complete
# Name: 4300, dtype: object
#
#
# Item number 6
# SalesDate             2021-05-01
# SalesID                     5228
# CustomerID                    24
# SalesPersonID                  7
# ProductID                     62
# Quantity         rQgB0KT6os5awe6
# Sales                      156.6
# StoreID                        6
# OrderStatus             Complete
# Name: 4933, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-23
# SalesID                2726
# CustomerID               47
# SalesPersonID             2
# ProductID                45
# Quantity                 UU
# Sales                 168.8
# StoreID                   8
# OrderStatus        Complete
# Name: 5858, dtype: object
#
#
# Item number 8
# SalesDate        2021-07-02
# SalesID                6378
# CustomerID               75
# SalesPersonID             1
# ProductID                68
# Quantity                  O
# Sales                  96.1
# StoreID                   7
# OrderStatus        Complete
# Name: 6157, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-29
# SalesID                2750
# CustomerID               46
# SalesPersonID             2
# ProductID                19
# Quantity                 kN
# Sales                 193.7
# StoreID                   3
# OrderStatus        Complete
# Name: 6527, dtype: object
#
#
# Item number 10
# SalesDate        2021-09-02
# SalesID                7461
# CustomerID               63
# SalesPersonID             8
# ProductID                 6
# Quantity            Z3R536u
# Sales                 180.4
# StoreID                   3
# OrderStatus        Complete
# Name: 7317, dtype: object
#
#
# Item number 11
# SalesDate         2021-12-05
# SalesID                 8366
# CustomerID                82
# SalesPersonID              1
# ProductID                 69
# Quantity         e6BFRUVcWp1
# Sales                   77.4
# StoreID                    3
# OrderStatus         Complete
# Name: 8332, dtype: object
#
#
# Item number 12
# SalesDate                        2021-12-11
# SalesID                                8471
# CustomerID                               66
# SalesPersonID                             6
# ProductID                                68
# Quantity         uAejNBVtIyaeWmnpljmiuOaGMs
# Sales                                  58.1
# StoreID                                   1
# OrderStatus                        Complete
# Name: 8437, dtype: object
#
#
#
#
# Accuracy checks:
# ======
#  non-complying rows for > 0 rule:
# Item number 1
# SalesDate        2020-02-08
# SalesID                 782
# CustomerID               39
# SalesPersonID             3
# ProductID                 6
# Quantity                  e
# Sales                  27.0
# StoreID                   1
# OrderStatus        Complete
# Name: 659, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-12
# SalesID                2211
# CustomerID                5
# SalesPersonID             3
# ProductID                55
# Quantity                  n
# Sales                 849.4
# StoreID                   1
# OrderStatus        Complete
# Name: 2160, dtype: object
#
#
# Item number 3
# SalesDate        2021-01-02
# SalesID                3376
# CustomerID               32
# SalesPersonID             1
# ProductID                68
# Quantity                  0
# Sales                 211.8
# StoreID                   5
# OrderStatus        Complete
# Name: 2722, dtype: object
#
#
# Item number 4
# SalesDate        2021-02-11
# SalesID                4150
# CustomerID               19
# SalesPersonID             9
# ProductID                21
# Quantity               SoKA
# Sales                 444.1
# StoreID                   1
# OrderStatus        Complete
# Name: 3669, dtype: object
#
#
# Item number 5
# SalesDate            2021-04-01
# SalesID                    4657
# CustomerID                   87
# SalesPersonID                 7
# ProductID                    14
# Quantity         S8dTEimdwH6723
# Sales                     248.7
# StoreID                       3
# OrderStatus            Complete
# Name: 4268, dtype: object
#
#
# Item number 6
# SalesDate        2021-04-01
# SalesID                4689
# CustomerID               19
# SalesPersonID             9
# ProductID                11
# Quantity             KBIEBM
# Sales                 282.8
# StoreID                   3
# OrderStatus        Complete
# Name: 4300, dtype: object
#
#
# Item number 7
# SalesDate             2021-05-01
# SalesID                     5228
# CustomerID                    24
# SalesPersonID                  7
# ProductID                     62
# Quantity         rQgB0KT6os5awe6
# Sales                      156.6
# StoreID                        6
# OrderStatus             Complete
# Name: 4933, dtype: object
#
#
# Item number 8
# SalesDate        2021-06-23
# SalesID                2726
# CustomerID               47
# SalesPersonID             2
# ProductID                45
# Quantity                 UU
# Sales                 168.8
# StoreID                   8
# OrderStatus        Complete
# Name: 5858, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-02
# SalesID                6378
# CustomerID               75
# SalesPersonID             1
# ProductID                68
# Quantity                  O
# Sales                  96.1
# StoreID                   7
# OrderStatus        Complete
# Name: 6157, dtype: object
#
#
# Item number 10
# SalesDate        2021-07-29
# SalesID                2750
# CustomerID               46
# SalesPersonID             2
# ProductID                19
# Quantity                 kN
# Sales                 193.7
# StoreID                   3
# OrderStatus        Complete
# Name: 6527, dtype: object
#
#
# Item number 11
# SalesDate        2021-09-02
# SalesID                7461
# CustomerID               63
# SalesPersonID             8
# ProductID                 6
# Quantity            Z3R536u
# Sales                 180.4
# StoreID                   3
# OrderStatus        Complete
# Name: 7317, dtype: object
#
#
# Item number 12
# SalesDate         2021-12-05
# SalesID                 8366
# CustomerID                82
# SalesPersonID              1
# ProductID                 69
# Quantity         e6BFRUVcWp1
# Sales                   77.4
# StoreID                    3
# OrderStatus         Complete
# Name: 8332, dtype: object
#
#
# Item number 13
# SalesDate                        2021-12-11
# SalesID                                8471
# CustomerID                               66
# SalesPersonID                             6
# ProductID                                68
# Quantity         uAejNBVtIyaeWmnpljmiuOaGMs
# Sales                                  58.1
# StoreID                                   1
# OrderStatus                        Complete
# Name: 8437, dtype: object

# %% [markdown]
# Find percentage non-compliance for each rule:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Run the validation check functions to find percentage non-compliance ↓↓↓</b>
# </div>

# %%
print('Consistency checks:')
print('======')
print('Quantity percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'Quantity', 'N', [4])))

print('Quantity percentage non-compliance for Integer type rule: ' + str(data_type_percentage_non_compliance(df, 'Quantity', int)))
print('\n')

print('Accuracy checks:')
print('======')
print('Quantity percentage non-compliance for > 0 rule: ' + str(numerical_range_percentage_non_compliance(df, 'Quantity', lower_bound = 0)))
# Out:
# Consistency checks:
# ======
# Quantity percentage non-compliance for data format: 0.14120969639915276
# Quantity percentage non-compliance for Integer type rule: 0.14120969639915276
#
#
# Accuracy checks:
# ======
# Quantity percentage non-compliance for > 0 rule: 0.15297717109908215

# %% [markdown]
# Calculate **Consistency** and **Accuracy** scores:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Calculate scores for Quantity column ↓↓↓</b>
# </div>

# %%
quantity_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'Quantity', 'N', [4]) + data_type_percentage_non_compliance(df, 'Quantity', int)) / 2
print('Consistency score: ' + str(quantity_consistency_score))

quantity_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'Quantity', lower_bound = 0)
print('Accuracy score: ' + str(quantity_accuracy_score))
# Out:
# Consistency score: 99.85879030360084
# Accuracy score: 99.84702282890092

# %% [markdown]
# ### Move on to validation checks for Sales column
# #### Identify rows in Sales column that do not comply with **Consistency** and **Accuracy** rules

# %%
print('Consistency checks:')
print('======')
print('Sales non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'Sales', 'N', [10,2]))
print('\n')

print('Sales non-complying rows for Float type rule:')
pprint_row_list(data_type_identify_non_complying_rows(df, 'Sales', float))
print('\n')

print('Accuracy checks:')
print('======')
print('Sales non-complying rows for > 0 rule:')
pprint_row_list(numerical_range_identify_non_complying_rows(df, 'Sales', lower_bound = 0))
# Out:
# Consistency checks:
# ======
# Sales non-complying rows for data format:
# Item number 1
# SalesDate         2020-01-03
# SalesID                  520
# CustomerID                73
# SalesPersonID              9
# ProductID                 13
# Quantity                  18
# Sales            WNl2tBcj5n1
# StoreID                    2
# OrderStatus         Complete
# Name: 341, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-10
# SalesID                2198
# CustomerID               63
# SalesPersonID             8
# ProductID                21
# Quantity                 13
# Sales                     R
# StoreID                   9
# OrderStatus        Complete
# Name: 2147, dtype: object
#
#
# Item number 3
# SalesDate        2020-12-01
# SalesID                2349
# CustomerID               39
# SalesPersonID             3
# ProductID                15
# Quantity                  5
# Sales                   eFU
# StoreID                   1
# OrderStatus        Complete
# Name: 2352, dtype: object
#
#
# Item number 4
# SalesDate        2021-01-13
# SalesID                2930
# CustomerID               79
# SalesPersonID             5
# ProductID                34
# Quantity                 19
# Sales              nCWAo9ag
# StoreID                   2
# OrderStatus        Complete
# Name: 3138, dtype: object
#
#
# Item number 5
# SalesDate        2021-05-01
# SalesID                5258
# CustomerID               19
# SalesPersonID             3
# ProductID                29
# Quantity                  6
# Sales               NB3Cu77
# StoreID                   1
# OrderStatus        Complete
# Name: 4963, dtype: object
#
#
# Item number 6
# SalesDate        2021-05-02
# SalesID                5288
# CustomerID               56
# SalesPersonID             7
# ProductID                62
# Quantity                 20
# Sales                     F
# StoreID                   4
# OrderStatus        Complete
# Name: 4993, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-01
# SalesID                5684
# CustomerID               32
# SalesPersonID             1
# ProductID                41
# Quantity                 13
# Sales                70.139
# StoreID                   1
# OrderStatus        Complete
# Name: 5427, dtype: object
#
#
# Item number 8
# SalesDate        2021-06-06
# SalesID                5989
# CustomerID               37
# SalesPersonID             3
# ProductID                40
# Quantity                 12
# Sales                   oOn
# StoreID                   7
# OrderStatus        Complete
# Name: 5732, dtype: object
#
#
# Item number 9
# SalesDate        2021-06-27
# SalesID                2563
# CustomerID                9
# SalesPersonID             4
# ProductID                46
# Quantity                 26
# Sales              oSZtOdKa
# StoreID                   8
# OrderStatus        Complete
# Name: 5865, dtype: object
#
#
# Item number 10
# SalesDate        2021-07-02
# SalesID                6461
# CustomerID               44
# SalesPersonID             8
# ProductID                16
# Quantity                 35
# Sales                 uwBoC
# StoreID                   6
# OrderStatus        Complete
# Name: 6240, dtype: object
#
#
# Item number 11
# SalesDate         2021-09-01
# SalesID                 7333
# CustomerID                73
# SalesPersonID              3
# ProductID                 11
# Quantity                  43
# Sales            q3ohlKqQ7Ed
# StoreID                    3
# OrderStatus         Complete
# Name: 7189, dtype: object
#
#
# Item number 12
# SalesDate        2021-10-06
# SalesID                7944
# CustomerID               80
# SalesPersonID             1
# ProductID                33
# Quantity                 26
# Sales            8MIQ7ct8wa
# StoreID                   1
# OrderStatus        Complete
# Name: 7836, dtype: object
#
#
# Item number 13
# SalesDate        2021-12-08
# SalesID                8422
# CustomerID               69
# SalesPersonID             4
# ProductID                19
# Quantity                  1
# Sales                    nf
# StoreID                   1
# OrderStatus        Complete
# Name: 8388, dtype: object
#
#
#
#
# Sales non-complying rows for Float type rule:
# Item number 1
# SalesDate         2020-01-03
# SalesID                  520
# CustomerID                73
# SalesPersonID              9
# ProductID                 13
# Quantity                  18
# Sales            WNl2tBcj5n1
# StoreID                    2
# OrderStatus         Complete
# Name: 341, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-10
# SalesID                2198
# CustomerID               63
# SalesPersonID             8
# ProductID                21
# Quantity                 13
# Sales                     R
# StoreID                   9
# OrderStatus        Complete
# Name: 2147, dtype: object
#
#
# Item number 3
# SalesDate        2020-12-01
# SalesID                2349
# CustomerID               39
# SalesPersonID             3
# ProductID                15
# Quantity                  5
# Sales                   eFU
# StoreID                   1
# OrderStatus        Complete
# Name: 2352, dtype: object
#
#
# Item number 4
# SalesDate        2021-01-13
# SalesID                2930
# CustomerID               79
# SalesPersonID             5
# ProductID                34
# Quantity                 19
# Sales              nCWAo9ag
# StoreID                   2
# OrderStatus        Complete
# Name: 3138, dtype: object
#
#
# Item number 5
# SalesDate        2021-05-01
# SalesID                5258
# CustomerID               19
# SalesPersonID             3
# ProductID                29
# Quantity                  6
# Sales               NB3Cu77
# StoreID                   1
# OrderStatus        Complete
# Name: 4963, dtype: object
#
#
# Item number 6
# SalesDate        2021-05-02
# SalesID                5288
# CustomerID               56
# SalesPersonID             7
# ProductID                62
# Quantity                 20
# Sales                     F
# StoreID                   4
# OrderStatus        Complete
# Name: 4993, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-06
# SalesID                5989
# CustomerID               37
# SalesPersonID             3
# ProductID                40
# Quantity                 12
# Sales                   oOn
# StoreID                   7
# OrderStatus        Complete
# Name: 5732, dtype: object
#
#
# Item number 8
# SalesDate        2021-06-27
# SalesID                2563
# CustomerID                9
# SalesPersonID             4
# ProductID                46
# Quantity                 26
# Sales              oSZtOdKa
# StoreID                   8
# OrderStatus        Complete
# Name: 5865, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-02
# SalesID                6461
# CustomerID               44
# SalesPersonID             8
# ProductID                16
# Quantity                 35
# Sales                 uwBoC
# StoreID                   6
# OrderStatus        Complete
# Name: 6240, dtype: object
#
#
# Item number 10
# SalesDate         2021-09-01
# SalesID                 7333
# CustomerID                73
# SalesPersonID              3
# ProductID                 11
# Quantity                  43
# Sales            q3ohlKqQ7Ed
# StoreID                    3
# OrderStatus         Complete
# Name: 7189, dtype: object
#
#
# Item number 11
# SalesDate        2021-10-06
# SalesID                7944
# CustomerID               80
# SalesPersonID             1
# ProductID                33
# Quantity                 26
# Sales            8MIQ7ct8wa
# StoreID                   1
# OrderStatus        Complete
# Name: 7836, dtype: object
#
#
# Item number 12
# SalesDate        2021-12-08
# SalesID                8422
# CustomerID               69
# SalesPersonID             4
# ProductID                19
# Quantity                  1
# Sales                    nf
# StoreID                   1
# OrderStatus        Complete
# Name: 8388, dtype: object
#
#
#
#
# Accuracy checks:
# ======
# Sales non-complying rows for > 0 rule:
# Item number 1
# SalesDate         2020-01-03
# SalesID                  520
# CustomerID                73
# SalesPersonID              9
# ProductID                 13
# Quantity                  18
# Sales            WNl2tBcj5n1
# StoreID                    2
# OrderStatus         Complete
# Name: 341, dtype: object
#
#
# Item number 2
# SalesDate        2020-09-10
# SalesID                2198
# CustomerID               63
# SalesPersonID             8
# ProductID                21
# Quantity                 13
# Sales                     R
# StoreID                   9
# OrderStatus        Complete
# Name: 2147, dtype: object
#
#
# Item number 3
# SalesDate        2020-12-01
# SalesID                2349
# CustomerID               39
# SalesPersonID             3
# ProductID                15
# Quantity                  5
# Sales                   eFU
# StoreID                   1
# OrderStatus        Complete
# Name: 2352, dtype: object
#
#
# Item number 4
# SalesDate        2021-01-13
# SalesID                2930
# CustomerID               79
# SalesPersonID             5
# ProductID                34
# Quantity                 19
# Sales              nCWAo9ag
# StoreID                   2
# OrderStatus        Complete
# Name: 3138, dtype: object
#
#
# Item number 5
# SalesDate        2021-05-01
# SalesID                5258
# CustomerID               19
# SalesPersonID             3
# ProductID                29
# Quantity                  6
# Sales               NB3Cu77
# StoreID                   1
# OrderStatus        Complete
# Name: 4963, dtype: object
#
#
# Item number 6
# SalesDate        2021-05-02
# SalesID                5288
# CustomerID               56
# SalesPersonID             7
# ProductID                62
# Quantity                 20
# Sales                     F
# StoreID                   4
# OrderStatus        Complete
# Name: 4993, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-06
# SalesID                5989
# CustomerID               37
# SalesPersonID             3
# ProductID                40
# Quantity                 12
# Sales                   oOn
# StoreID                   7
# OrderStatus        Complete
# Name: 5732, dtype: object
#
#
# Item number 8
# SalesDate        2021-06-27
# SalesID                2563
# CustomerID                9
# SalesPersonID             4
# ProductID                46
# Quantity                 26
# Sales              oSZtOdKa
# StoreID                   8
# OrderStatus        Complete
# Name: 5865, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-02
# SalesID                6461
# CustomerID               44
# SalesPersonID             8
# ProductID                16
# Quantity                 35
# Sales                 uwBoC
# StoreID                   6
# OrderStatus        Complete
# Name: 6240, dtype: object
#
#
# Item number 10
# SalesDate         2021-09-01
# SalesID                 7333
# CustomerID                73
# SalesPersonID              3
# ProductID                 11
# Quantity                  43
# Sales            q3ohlKqQ7Ed
# StoreID                    3
# OrderStatus         Complete
# Name: 7189, dtype: object
#
#
# Item number 11
# SalesDate        2021-10-06
# SalesID                7944
# CustomerID               80
# SalesPersonID             1
# ProductID                33
# Quantity                 26
# Sales            8MIQ7ct8wa
# StoreID                   1
# OrderStatus        Complete
# Name: 7836, dtype: object
#
#
# Item number 12
# SalesDate        2021-12-08
# SalesID                8422
# CustomerID               69
# SalesPersonID             4
# ProductID                19
# Quantity                  1
# Sales                    nf
# StoreID                   1
# OrderStatus        Complete
# Name: 8388, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for each rule:

# %%
print('Consistency checks:')
print('======')
print('Sales percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'Sales', 'N', [10,2])))

print('Sales percentage non-compliance for Float type rule: ' + str(data_type_percentage_non_compliance(df, 'Sales', float)))
print('\n')

print('Accuracy checks:')
print('======')
print('Sales percentage non-compliance for >= 0 rule: ')
print(numerical_range_percentage_non_compliance(df, 'Sales', lower_bound = -0.001))
# Out:
# Consistency checks:
# ======
# Sales percentage non-compliance for data format: 0.15297717109908215
# Sales percentage non-compliance for Float type rule: 0.14120969639915276
#
#
# Accuracy checks:
# ======
# Sales percentage non-compliance for >= 0 rule:
# 0.14120969639915276

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
sales_consistency_score = 100 - (data_format_percentage_non_compliance(df, 'Sales', 'N', [10,2]) + data_type_percentage_non_compliance(df, 'Sales', float)) / 2
print('Consistency score: ' + str(sales_consistency_score))

sales_accuracy_score = 100 - numerical_range_percentage_non_compliance(df, 'Sales', lower_bound = -0.001)
print('Accuracy score: ' + str(sales_accuracy_score))
# Out:
# Consistency score: 99.85290656625088
# Accuracy score: 99.85879030360084

# %% [markdown]
# ### Move on to validation checks for StoreID column
# #### Identify rows in StoreID column that do not comply with **Consistency** and **Accuracy** rules

# %%
print('Consistency checks:')
print('======')
print('StoreID non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'StoreID', 'N', [1]))
# Out:
# Consistency checks:
# ======
# StoreID non-complying rows for data format:
# Item number 1
# SalesDate          2020-01-01
# SalesID                   115
# CustomerID                  3
# SalesPersonID               9
# ProductID                  11
# Quantity                   60
# Sales                  1683.8
# StoreID          nd68G6h0PZbk
# OrderStatus           Pending
# Name: 4, dtype: object
#
#
# Item number 2
# SalesDate        2020-02-01
# SalesID                 584
# CustomerID               28
# SalesPersonID             5
# ProductID                24
# Quantity                 11
# Sales                  58.2
# StoreID                  -2
# OrderStatus        Complete
# Name: 517, dtype: object
#
#
# Item number 3
# SalesDate           2020-04-15
# SalesID                   1114
# CustomerID                  16
# SalesPersonID                2
# ProductID                   22
# Quantity                    12
# Sales                     47.5
# StoreID          OybsWeAABRihQ
# OrderStatus           Complete
# Name: 1210, dtype: object
#
#
# Item number 4
# SalesDate        2020-05-02
# SalesID                1371
# CustomerID               73
# SalesPersonID             9
# ProductID                76
# Quantity                  7
# Sales                2671.2
# StoreID                 dBA
# OrderStatus        Complete
# Name: 1335, dtype: object
#
#
# Item number 5
# SalesDate        2021-01-02
# SalesID                3355
# CustomerID               80
# SalesPersonID             1
# ProductID                29
# Quantity                 11
# Sales                1259.2
# StoreID                  44
# OrderStatus        Complete
# Name: 2701, dtype: object
#
#
# Item number 6
# SalesDate        2021-03-01
# SalesID                4197
# CustomerID               40
# SalesPersonID             4
# ProductID                33
# Quantity                  7
# Sales                 177.3
# StoreID                  kX
# OrderStatus        Complete
# Name: 3732, dtype: object
#
#
# Item number 7
# SalesDate        2021-04-02
# SalesID                4815
# CustomerID               63
# SalesPersonID             8
# ProductID                76
# Quantity                 90
# Sales               36462.6
# StoreID                  Oc
# OrderStatus        Complete
# Name: 4428, dtype: object
#
#
# Item number 8
# SalesDate        2021-06-05
# SalesID                5978
# CustomerID               46
# SalesPersonID             3
# ProductID                72
# Quantity                 22
# Sales                 219.1
# StoreID            w3VbbUt5
# OrderStatus        Complete
# Name: 5721, dtype: object
#
#
# Item number 9
# SalesDate        2021-07-02
# SalesID                6293
# CustomerID               39
# SalesPersonID             3
# ProductID                36
# Quantity                 46
# Sales                 350.5
# StoreID                  14
# OrderStatus        Complete
# Name: 6072, dtype: object
#
#
# Item number 10
# SalesDate        2021-08-01
# SalesID                6716
# CustomerID               41
# SalesPersonID             5
# ProductID                25
# Quantity                 10
# Sales                 138.0
# StoreID                  31
# OrderStatus        Complete
# Name: 6533, dtype: object
#
#
# Item number 11
# SalesDate        2021-08-10
# SalesID                7181
# CustomerID               44
# SalesPersonID             8
# ProductID                30
# Quantity                 15
# Sales                 384.7
# StoreID                 HQ0
# OrderStatus        Complete
# Name: 6999, dtype: object
#
#
# Item number 12
# SalesDate        2021-08-29
# SalesID                2602
# CustomerID               18
# SalesPersonID             6
# ProductID                10
# Quantity                 11
# Sales                  76.5
# StoreID                   a
# OrderStatus        Complete
# Name: 7106, dtype: object
#
#
# Item number 13
# SalesDate        2021-10-18
# SalesID                2795
# CustomerID                2
# SalesPersonID             3
# ProductID                19
# Quantity                  7
# Sales                  54.9
# StoreID                 lMp
# OrderStatus        Complete
# Name: 7946, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for data format rule:

# %%
print('Consistency checks:')
print('======')
print('StoreID percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'StoreID', 'N', [1])))
# Out:
# Consistency checks:
# ======
# StoreID percentage non-compliance for data format: 0.15297717109908215

# %% [markdown]
# # Using ChatGPT to generate validation check function - **Accuracy**
# ### Check that all values in StoreID Column contain only the permitted values (1 - 9)

# %%
def check_store_id_quality(df):
    # Define the permitted values
    permitted_values = {'1', '2', '3', '4', '5', '6', '7', '8', '9'}

    # Filter rows where 'StoreID' is not in the permitted values
    invalid_rows = df[~df['StoreID'].isin(permitted_values)]

    # Return the invalid rows as a list of dictionaries
    return invalid_rows.to_dict(orient='records')

# %% [markdown]
# #### Run the check defined by ChatGPT to identify rows in StoreID column that do not comply with permitted values rule

# %%
print('Consistency checks:')
print('======')
print('StoreID non-complying rows for permitted values:')
print(check_store_id_quality(df))
# Out:
# Consistency checks:
# ======
# StoreID non-complying rows for permitted values:
# [{'SalesDate': '2020-01-01', 'SalesID': '115', 'CustomerID': '3', 'SalesPersonID': '9', 'ProductID': '11', 'Quantity': '60', 'Sales': '1683.8', 'StoreID': 'nd68G6h0PZbk', 'OrderStatus': 'Pending'}, {'SalesDate': '2020-02-01', 'SalesID': '584', 'CustomerID': '28', 'SalesPersonID': '5', 'ProductID': '24', 'Quantity': '11', 'Sales': '58.2', 'StoreID': '-2', 'OrderStatus': 'Complete'}, {'SalesDate': '2020-04-15', 'SalesID': '1114', 'CustomerID': '16', 'SalesPersonID': '2', 'ProductID': '22', 'Quantity': '12', 'Sales': '47.5', 'StoreID': 'OybsWeAABRihQ', 'OrderStatus': 'Complete'}, {'SalesDate': '2020-05-02', 'SalesID': '1371', 'CustomerID': '73', 'SalesPersonID': '9', 'ProductID': '76', 'Quantity': '7', 'Sales': '2671.2', 'StoreID': 'dBA', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-01-02', 'SalesID': '3355', 'CustomerID': '80', 'SalesPersonID': '1', 'ProductID': '29', 'Quantity': '11', 'Sales': '1259.2', 'StoreID': '44', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-03-01', 'SalesID': '4197', 'CustomerID': '40', 'SalesPersonID': '4', 'ProductID': '33', 'Quantity': '7', 'Sales': '177.3', 'StoreID': 'kX', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-04-02', 'SalesID': '4815', 'CustomerID': '63', 'SalesPersonID': '8', 'ProductID': '76', 'Quantity': '90', 'Sales': '36462.6', 'StoreID': 'Oc', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-06-05', 'SalesID': '5978', 'CustomerID': '46', 'SalesPersonID': '3', 'ProductID': '72', 'Quantity': '22', 'Sales': '219.1', 'StoreID': 'w3VbbUt5', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-07-02', 'SalesID': '6293', 'CustomerID': '39', 'SalesPersonID': '3', 'ProductID': '36', 'Quantity': '46', 'Sales': '350.5', 'StoreID': '14', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-08-01', 'SalesID': '6716', 'CustomerID': '41', 'SalesPersonID': '5', 'ProductID': '25', 'Quantity': '10', 'Sales': '138.0', 'StoreID': '31', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-08-10', 'SalesID': '7181', 'CustomerID': '44', 'SalesPersonID': '8', 'ProductID': '30', 'Quantity': '15', 'Sales': '384.7', 'StoreID': 'HQ0', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-08-29', 'SalesID': '2602', 'CustomerID': '18', 'SalesPersonID': '6', 'ProductID': '10', 'Quantity': '11', 'Sales': '76.5', 'StoreID': 'a', 'OrderStatus': 'Complete'}, {'SalesDate': '2021-10-18', 'SalesID': '2795', 'CustomerID': '2', 'SalesPersonID': '3', 'ProductID': '19', 'Quantity': '7', 'Sales': '54.9', 'StoreID': 'lMp', 'OrderStatus': 'Complete'}]

# %% [markdown]
# #### Find percentage non-compliance for permitted values rule:

# %%
store_id_permitted_values_percentage_non_compliance = len(check_store_id_quality(df)) / l * 100

# %%
print('Accuracy checks:')
print('======')
print('StoreID percentage non-compliance for permitted values: ' + str(store_id_permitted_values_percentage_non_compliance))
# Out:
# Accuracy checks:
# ======
# StoreID percentage non-compliance for permitted values: 0.15297717109908215

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
store_id_consistency_score = 100 - data_format_percentage_non_compliance(df, 'StoreID', 'N', [1])
print('Consistency score: ' + str(store_id_consistency_score))

store_id_accuracy_score = 100 - store_id_permitted_values_percentage_non_compliance
print('Accuracy score: ' + str(store_id_accuracy_score))
# Out:
# Consistency score: 99.84702282890092
# Accuracy score: 99.84702282890092

# %% [markdown]
# ### Move on to OrderStatus column
# #### Identify rows in OrderStatus column that do not comply with data format rule:

# %%
print('Consistency checks:')
print('======')
print('OrderStatus non-complying rows for data format:')
pprint_row_list(data_format_identify_non_complying_rows(df, 'OrderStatus', 'A', [10]))
# Out:
# Consistency checks:
# ======
# OrderStatus non-complying rows for data format:
# Item number 1
# SalesDate          2020-02-07
# SalesID                   775
# CustomerID                  5
# SalesPersonID               9
# ProductID                  35
# Quantity                    7
# Sales                    38.5
# StoreID                     4
# OrderStatus      rTc8Le3iHuV6
# Name: 652, dtype: object
#
#
# Item number 2
# SalesDate        2020-04-01
# SalesID                1075
# CustomerID               32
# SalesPersonID             1
# ProductID                62
# Quantity                  5
# Sales                 161.0
# StoreID                   1
# OrderStatus             2Jk
# Name: 1077, dtype: object
#
#
# Item number 3
# SalesDate        2020-04-07
# SalesID                1230
# CustomerID               19
# SalesPersonID             9
# ProductID                49
# Quantity                 36
# Sales                 899.8
# StoreID                   2
# OrderStatus          l4cNSE
# Name: 1178, dtype: object
#
#
# Item number 4
# SalesDate                            2020-08-11
# SalesID                                    2016
# CustomerID                                    3
# SalesPersonID                                 9
# ProductID                                    57
# Quantity                                      5
# Sales                                     101.9
# StoreID                                       5
# OrderStatus      nCYNj2qGHfSVTaNOTaeigVRyaoajW5
# Name: 1981, dtype: object
#
#
# Item number 5
# SalesDate          2021-01-03
# SalesID                  3566
# CustomerID                 69
# SalesPersonID               4
# ProductID                  35
# Quantity                    3
# Sales                    22.2
# StoreID                     1
# OrderStatus      TR3OMwFdOBEF
# Name: 2916, dtype: object
#
#
# Item number 6
# SalesDate                2021-03-19
# SalesID                        2499
# CustomerID                       44
# SalesPersonID                     7
# ProductID                        75
# Quantity                         19
# Sales                         155.8
# StoreID                           7
# OrderStatus      RVD63ltyufaIkUaTHo
# Name: 4217, dtype: object
#
#
# Item number 7
# SalesDate        2021-06-01
# SalesID                5685
# CustomerID               32
# SalesPersonID             4
# ProductID                43
# Quantity                 42
# Sales                 589.9
# StoreID                   1
# OrderStatus             5ji
# Name: 5428, dtype: object
#
#
# Item number 8
# SalesDate          2021-08-02
# SalesID                  7008
# CustomerID                 61
# SalesPersonID               3
# ProductID                  41
# Quantity                    5
# Sales                    54.0
# StoreID                     5
# OrderStatus      kRIT3I2xQqtQ
# Name: 6826, dtype: object
#
#
# Item number 9
# SalesDate        2021-09-01
# SalesID                7268
# CustomerID               79
# SalesPersonID             8
# ProductID                19
# Quantity                 12
# Sales                 111.7
# StoreID                   7
# OrderStatus          Mtb4Lo
# Name: 7124, dtype: object
#
#
# Item number 10
# SalesDate        2021-09-02
# SalesID                7532
# CustomerID               76
# SalesPersonID             4
# ProductID                77
# Quantity                 27
# Sales                 373.7
# StoreID                   9
# OrderStatus      Python!1!1
# Name: 7388, dtype: object
#
#
# Item number 11
# SalesDate        2021-10-05
# SalesID                7899
# CustomerID               56
# SalesPersonID             8
# ProductID                31
# Quantity                  9
# Sales                  79.5
# StoreID                   3
# OrderStatus               1
# Name: 7791, dtype: object

# %% [markdown]
# #### Find percentage non-compliance for data format rule:

# %%
print('Consistency checks:')
print('======')
print('OrderStatus percentage non-compliance for data format: ' + str(data_format_percentage_non_compliance(df, 'OrderStatus', 'A', [10])))
# Out:
# Consistency checks:
# ======
# OrderStatus percentage non-compliance for data format: 0.12944222169922334

# %% [markdown]
# # Using ChatGPT to generate validation check function - **Accuracy**
# ### check that all values in the  'OrderStatus' column contain only the permitted values (Complete, Pending, Incomplete)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Get ChatGPT to write the Accuracy check function ↓↓↓</b>
# </div>

# %%
def check_order_status_quality(df):
    # Define the permitted values
    permitted_values = {'Complete', 'Pending', 'Incomplete'}

    # Filter rows where 'StoreID' is not in the permitted values
    invalid_rows = df[~df['OrderStatus'].isin(permitted_values)]

    # Return the invalid rows as a list of dictionaries
    return invalid_rows.to_dict(orient='records')

# %% [markdown]
# #### Run the check defined by ChatGPT to identify rows in OrderStatus column that do not comply with permitted values rule

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>↓↓↓ TO DO: Run the check and print the results ↓↓↓</b>
# </div>

# %%
print('Consistency checks:')
print('======')
print('OrderStatus non-complying rows for permitted values:')
order_status_permitted_values_non_compliers = check_order_status_quality(df) # call the function defined by ChatGPT
print(order_status_permitted_values_non_compliers)
# Out:
# Consistency checks:
# ======
# OrderStatus non-complying rows for permitted values:
# [{'SalesDate': '2020-02-07', 'SalesID': '775', 'CustomerID': '5', 'SalesPersonID': '9', 'ProductID': '35', 'Quantity': '7', 'Sales': '38.5', 'StoreID': '4', 'OrderStatus': 'rTc8Le3iHuV6'}, {'SalesDate': '2020-04-01', 'SalesID': '1075', 'CustomerID': '32', 'SalesPersonID': '1', 'ProductID': '62', 'Quantity': '5', 'Sales': '161.0', 'StoreID': '1', 'OrderStatus': '2Jk'}, {'SalesDate': '2020-04-07', 'SalesID': '1230', 'CustomerID': '19', 'SalesPersonID': '9', 'ProductID': '49', 'Quantity': '36', 'Sales': '899.8', 'StoreID': '2', 'OrderStatus': 'l4cNSE'}, {'SalesDate': '2020-07-13', 'SalesID': '1662', 'CustomerID': '13', 'SalesPersonID': '3', 'ProductID': '21', 'Quantity': '10', 'Sales': '101.4', 'StoreID': '9', 'OrderStatus': 'QhIX'}, {'SalesDate': '2020-08-11', 'SalesID': '2016', 'CustomerID': '3', 'SalesPersonID': '9', 'ProductID': '57', 'Quantity': '5', 'Sales': '101.9', 'StoreID': '5', 'OrderStatus': 'nCYNj2qGHfSVTaNOTaeigVRyaoajW5'}, {'SalesDate': '2021-01-02', 'SalesID': '3104', 'CustomerID': '127', 'SalesPersonID': '3', 'ProductID': '7', 'Quantity': '10', 'Sales': '413.8', 'StoreID': '9', 'OrderStatus': 'YgU'}, {'SalesDate': '2021-01-03', 'SalesID': '3566', 'CustomerID': '69', 'SalesPersonID': '4', 'ProductID': '35', 'Quantity': '3', 'Sales': '22.2', 'StoreID': '1', 'OrderStatus': 'TR3OMwFdOBEF'}, {'SalesDate': '2021-01-06', 'SalesID': '2893', 'CustomerID': '6', 'SalesPersonID': '8', 'ProductID': '18', 'Quantity': '10', 'Sales': '255.2', 'StoreID': '3', 'OrderStatus': 'lFL'}, {'SalesDate': '2021-03-02', 'SalesID': '4277', 'CustomerID': '80', 'SalesPersonID': '4', 'ProductID': '43', 'Quantity': '9', 'Sales': '102.3', 'StoreID': '2', 'OrderStatus': 'I'}, {'SalesDate': '2021-03-19', 'SalesID': '2499', 'CustomerID': '44', 'SalesPersonID': '7', 'ProductID': '75', 'Quantity': '19', 'Sales': '155.8', 'StoreID': '7', 'OrderStatus': 'RVD63ltyufaIkUaTHo'}, {'SalesDate': '2021-03-30', 'SalesID': '2887', 'CustomerID': '42', 'SalesPersonID': '1', 'ProductID': '13', 'Quantity': '7', 'Sales': '173.3', 'StoreID': '1', 'OrderStatus': 'gIB'}, {'SalesDate': '2021-06-01', 'SalesID': '5685', 'CustomerID': '32', 'SalesPersonID': '4', 'ProductID': '43', 'Quantity': '42', 'Sales': '589.9', 'StoreID': '1', 'OrderStatus': '5ji'}, {'SalesDate': '2021-07-01', 'SalesID': '6189', 'CustomerID': '56', 'SalesPersonID': '8', 'ProductID': '53', 'Quantity': '10', 'Sales': '615.0', 'StoreID': '7', 'OrderStatus': 'Love'}, {'SalesDate': '2021-08-02', 'SalesID': '7008', 'CustomerID': '61', 'SalesPersonID': '3', 'ProductID': '41', 'Quantity': '5', 'Sales': '54.0', 'StoreID': '5', 'OrderStatus': 'kRIT3I2xQqtQ'}, {'SalesDate': '2021-09-01', 'SalesID': '7268', 'CustomerID': '79', 'SalesPersonID': '8', 'ProductID': '19', 'Quantity': '12', 'Sales': '111.7', 'StoreID': '7', 'OrderStatus': 'Mtb4Lo'}, {'SalesDate': '2021-09-02', 'SalesID': '7433', 'CustomerID': '74', 'SalesPersonID': '4', 'ProductID': '16', 'Quantity': '3', 'Sales': '31.0', 'StoreID': '4', 'OrderStatus': 'n'}, {'SalesDate': '2021-09-02', 'SalesID': '7532', 'CustomerID': '76', 'SalesPersonID': '4', 'ProductID': '77', 'Quantity': '27', 'Sales': '373.7', 'StoreID': '9', 'OrderStatus': 'Python!1!1'}, {'SalesDate': '2021-09-02', 'SalesID': '7635', 'CustomerID': '19', 'SalesPersonID': '4', 'ProductID': '35', 'Quantity': '74', 'Sales': '497.1', 'StoreID': '1', 'OrderStatus': 'q'}, {'SalesDate': '2021-10-05', 'SalesID': '7899', 'CustomerID': '56', 'SalesPersonID': '8', 'ProductID': '31', 'Quantity': '9', 'Sales': '79.5', 'StoreID': '3', 'OrderStatus': '1'}, {'SalesDate': '2021-10-05', 'SalesID': '7907', 'CustomerID': '82', 'SalesPersonID': '1', 'ProductID': '39', 'Quantity': '32', 'Sales': '1679.7', 'StoreID': '1', 'OrderStatus': 'n'}]

# %% [markdown]
# #### Find percentage non-compliance for permitted values rule:

# %%
order_status_permitted_values_percentage_non_compliance = len(order_status_permitted_values_non_compliers) / l * 100

# %%
print('Accuracy checks:')
print('======')
print('OrderStatus percentage non-compliance for permitted values: ' + str(order_status_permitted_values_percentage_non_compliance))
# Out:
# Accuracy checks:
# ======
# OrderStatus percentage non-compliance for permitted values: 0.2353494939985879

# %% [markdown]
# #### Calculate **Consistency** and **Accuracy** scores:

# %%
order_status_consistency_score = 100 - data_format_percentage_non_compliance(df, 'OrderStatus', 'A', [10])
print('Consistency score: ' + str(order_status_consistency_score))

order_status_accuracy_score = 100 - order_status_permitted_values_percentage_non_compliance
print('Accuracy score: ' + str(order_status_accuracy_score))
# Out:
# Consistency score: 99.87055777830078
# Accuracy score: 99.76465050600142

# %% [markdown]
# # Reporting of Overall Dataset quality
# ## Calculate and present overall **Completeness**, **Consistency**, **Accuracy** scores of dataset

# %% [markdown]
# **Completeness** score of entire dataset = average of **Completeness** scores for each column

# %%
# remember earlier we found that every column passed the Completeness check - 100% completeness!
dataset_completeness_score = 100

# %% [markdown]
# **Consistency** score of entire dataset = average of **Consistency** scores for each column

# %%
dataset_consistency_score = (sales_date_consistency_score
+ sales_id_consistency_score
+ customer_id_consistency_score
+ salesperson_id_consistency_score
+ product_id_consistency_score
+ quantity_consistency_score
+ sales_consistency_score
+ store_id_consistency_score
+ order_status_consistency_score) / 9

# %% [markdown]
# **Accuracy** score of entire dataset = average of **Accuracy** scores for each column

# %%
dataset_accuracy_score = (sales_date_accuracy_score
+ sales_id_accuracy_score
+ customer_id_accuracy_score
+ salesperson_id_accuracy_score
+ product_id_accuracy_score
+ quantity_accuracy_score
+ sales_accuracy_score
+ store_id_accuracy_score
+ order_status_accuracy_score) / 9

# %% [markdown]
# Present the results in a table:

# %%
completeness_target = 100
consistency_target = 100
accuracy_target = 90

# %%
def get_pass_fail (performance, target):
	if performance >= target:
		return 'Pass'
	return 'Fail'

# %%
results_header_row = '| ' + 'METRIC'.ljust(15) + ' | ' + 'PERFORMANCE'.ljust(15) + ' | ' + 'TARGET'.ljust(15) + ' | ' + 'PASS / FAIL'.ljust(15) + ' |'

results_completeness_row = '| ' + 'Completeness'.ljust(15) + ' | ' + str(dataset_completeness_score)[:6].ljust(15) + ' | ' + str(completeness_target).ljust(15) + ' | ' + get_pass_fail(dataset_completeness_score, completeness_target).ljust(15) + ' |'

results_consistency_row = '| ' + 'Consistency'.ljust(15) + ' | ' + str(dataset_consistency_score)[:6].ljust(15) + ' | ' + str(consistency_target).ljust(15) + ' | ' + get_pass_fail(dataset_consistency_score, consistency_target).ljust(15) + ' |'

results_accuracy_row = '| ' + 'Accuracy'.ljust(15) + ' | ' + str(dataset_accuracy_score)[:6].ljust(15) + ' | ' + str(accuracy_target).ljust(15) + ' | ' + get_pass_fail(dataset_accuracy_score, accuracy_target).ljust(15) + ' |'

results_divider = '+ ' + ''.ljust(15, '-') + ' + ' + ''.ljust(15, '-') + ' + ' + ''.ljust(15, '-') + ' + ' + ''.ljust(15, '-') + ' +'
results_header_divider = '+ ' + ''.ljust(15, '=') + ' + ' + ''.ljust(15, '=') + ' + ' + ''.ljust(15, '=') + ' + ' + ''.ljust(15, '=') + ' +'

# %%
print(results_divider)
print(results_header_row)
print(results_header_divider)
print(results_completeness_row)
print(results_divider)
print(results_consistency_row)
print(results_divider)
print(results_accuracy_row)
print(results_divider)
# Out:
# + --------------- + --------------- + --------------- + --------------- +
# | METRIC          | PERFORMANCE     | TARGET          | PASS / FAIL     |
# + =============== + =============== + =============== + =============== +
# | Completeness    | 100             | 100             | Pass            |
# + --------------- + --------------- + --------------- + --------------- +
# | Consistency     | 99.846          | 100             | Fail            |
# + --------------- + --------------- + --------------- + --------------- +
# | Accuracy        | 99.841          | 90              | Pass            |
# + --------------- + --------------- + --------------- + --------------- +
